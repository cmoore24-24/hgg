# %%
import uproot
import awkward as ak
import numpy as np
import json

# %%
file = uproot.open('fitDiagnosticsTest.root')

# %%
list(file)
# Out:
# ['shapes_prefit;1',
#  'shapes_prefit/ptbin0fail2017;1',
#  'shapes_prefit/ptbin0fail2017/data;1',
#  'shapes_prefit/ptbin0fail2017/hbb;1',
#  'shapes_prefit/ptbin0fail2017/hgg;1',
#  'shapes_prefit/ptbin0fail2017/hww;1',
#  'shapes_prefit/ptbin0fail2017/singletop;1',
#  'shapes_prefit/ptbin0fail2017/ttboosted;1',
#  'shapes_prefit/ptbin0fail2017/wqq;1',
#  'shapes_prefit/ptbin0fail2017/ww;1',
#  'shapes_prefit/ptbin0fail2017/wz;1',
#  'shapes_prefit/ptbin0fail2017/zqq;1',
#  'shapes_prefit/ptbin0fail2017/zz;1',
#  'shapes_prefit/ptbin0fail2017/qcd;1',
#  'shapes_prefit/ptbin0fail2017/total;1',
#  'shapes_prefit/ptbin0fail2017/total_signal;1',
#  'shapes_prefit/ptbin0fail2017/total_background;1',
#  'shapes_prefit/ptbin0fail2017/total_covar;1',
#  'shapes_prefit/ptbin0pass2017;1',
#  'shapes_prefit/ptbin0pass2017/data;1',
#  'shapes_prefit/ptbin0pass2017/hbb;1',
#  'shapes_prefit/ptbin0pass2017/hgg;1',
#  'shapes_prefit/ptbin0pass2017/hww;1',
# ...

# %%
[i for i in file['tree_fit_b'].items() if 'mcstat' not in i[0]]
# Out:
# [('fit_status', <TBranch 'fit_status' at 0x7f4e05e382e0>),
#  ('r', <TBranch 'r' at 0x7f4e05e38b20>),
#  ('rErr', <TBranch 'rErr' at 0x7f4e05e3e310>),
#  ('rLoErr', <TBranch 'rLoErr' at 0x7f4e05e3eac0>),
#  ('rHiErr', <TBranch 'rHiErr' at 0x7f4e05e442b0>),
#  ('numbadnll', <TBranch 'numbadnll' at 0x7f4e05e44a60>),
#  ('nll_min', <TBranch 'nll_min' at 0x7f4e05e49250>),
#  ('CMS_gghgg_e_veto_2017_In',
#   <TBranch 'CMS_gghgg_e_veto_2017_In' at 0x7f4e05e49a00>),
#  ('CMS_gghgg_m_veto_2017_In',
#   <TBranch 'CMS_gghgg_m_veto_2017_In' at 0x7f4e05e50220>),
#  ('CMS_gghgg_tau_veto_2017_In',
#   <TBranch 'CMS_gghgg_tau_veto_2017_In' at 0x7f4e05e509d0>),
#  ('CMS_lumi_13TeV_1718_In',
#   <TBranch 'CMS_lumi_13TeV_1718_In' at 0x7f4e05e561c0>),
#  ('CMS_lumi_13TeV_2017_In',
#   <TBranch 'CMS_lumi_13TeV_2017_In' at 0x7f4e05e56970>),
#  ('CMS_lumi_13TeV_correlated_In',
#   <TBranch 'CMS_lumi_13TeV_correlated_In' at 0x7f4e04dc2160>),
#  ('tf2017_MCtempl_deco1_In',
# ...

# %%
fit = uproot.open('shapes2017.root')

# %%
list(fit)
# Out:
# ['shapes2017;1', 'ProcessID0;1']
