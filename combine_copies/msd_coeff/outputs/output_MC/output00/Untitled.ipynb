# %%
import uproot
import matplotlib.pyplot as plt

# %%
file = uproot.open('fitDiagnosticsTest.root')

# %%
arr = file['shapes_fit_s']['ptbin0pass2017/total'].to_numpy()

# %%
plt.stairs(arr[0], arr[1])
