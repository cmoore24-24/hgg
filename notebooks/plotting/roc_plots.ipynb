# %%
import numpy as np
import matplotlib.pyplot as plt 
import pickle

# %%
with open('../../outputs/big_btagged_antikt_result.pkl', 'rb') as f:
    btagged = pickle.load(f)
with open('../../outputs/big_not_btagged_antikt_result.pkl', 'rb') as f:
    not_btagged = pickle.load(f)

# %%
#Signal scale factor
scalesHJ = ((44.99*(0.471*1000)*0.0817)/(not_btagged[0]['Hgg']['Hgg']['entries']))
bscalesHJ = ((44.99*(0.471*1000)*0.0817)/(btagged[0]['Hgg']['Hgg']['entries']))
#Hbb scale factor
scalesHbb = ((44.99*(0.274*1000)*0.581)/(not_btagged[0]['Hbb']['Hbb']['entries']))
bscalesHbb = ((44.99*(0.274*1000)*0.581)/(btagged[0]['Hbb']['Hbb']['entries']))

# %%
######Hbb scalings
not_btagged[0]['Hbb']['Hbb']['Color_Ring'].view(flow=True)[:] *= scalesHbb
# not_btagged[0]['Hbb']['Hbb']['Color_Ring_Groomed'].view(flow=True)[:] *= scalesHbb
# not_btagged[0]['Hbb']['Hbb']['Color_Ring_Var'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['N2'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['N3'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['nConstituents'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['Mass'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['SDmass'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['Btag'].view(flow=True)[:] *= scalesHbb
not_btagged[0]['Hbb']['Hbb']['D2'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hbb']['Hbb']['D3'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hbb']['Hbb']['N4'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hbb']['Hbb']['U1'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hbb']['Hbb']['U2'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hbb']['Hbb']['U3'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['Color_Ring'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hbb']['Hbb']['Color_Ring_Groomed'].view(flow=True)[:] *= scalesHbb
# btagged[0]['Hbb']['Hbb']['Color_Ring_Var'].view(flow=True)[:] *= scalesHbb
btagged[0]['Hbb']['Hbb']['N2'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['N3'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['nConstituents'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['Mass'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['SDmass'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['Btag'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hbb']['Hbb']['D2'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hbb']['Hbb']['D3'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hbb']['Hbb']['N4'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hbb']['Hbb']['U1'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hbb']['Hbb']['U2'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hbb']['Hbb']['U3'].view(flow=True)[:] *= bscalesHbb
######Hgg scalings
not_btagged[0]['Hgg']['Hgg']['Color_Ring'].view(flow=True)[:] *= scalesHJ
# not_btagged[0]['Hgg']['Hgg']['Color_Ring_Groomed'].view(flow=True)[:] *= scalesHJ
# not_btagged[0]['Hgg']['Hgg']['Color_Ring_Var'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['N2'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['N3'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['nConstituents'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['Mass'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['SDmass'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['Btag'].view(flow=True)[:] *= scalesHJ
not_btagged[0]['Hgg']['Hgg']['D2'].view(flow=True)[:] *= bscalesHJ
# not_btagged[0]['Hgg']['Hgg']['D3'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hgg']['Hgg']['N4'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hgg']['Hgg']['U1'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hgg']['Hgg']['U2'].view(flow=True)[:] *= bscalesHbb
# not_btagged[0]['Hgg']['Hgg']['U3'].view(flow=True)[:] *= bscalesHbb
btagged[0]['Hgg']['Hgg']['Color_Ring'].view(flow=True)[:] *= bscalesHJ
# btagged[0]['Hgg']['Hgg']['Color_Ring_Groomed'].view(flow=True)[:] *= scalesHJ
# btagged[0]['Hgg']['Hgg']['Color_Ring_Var'].view(flow=True)[:] *= scalesHJ
btagged[0]['Hgg']['Hgg']['N2'].view(flow=True)[:] *= bscalesHJ
btagged[0]['Hgg']['Hgg']['N3'].view(flow=True)[:] *= bscalesHJ
btagged[0]['Hgg']['Hgg']['nConstituents'].view(flow=True)[:] *= bscalesHJ
btagged[0]['Hgg']['Hgg']['Mass'].view(flow=True)[:] *= bscalesHJ
btagged[0]['Hgg']['Hgg']['SDmass'].view(flow=True)[:] *= bscalesHJ
btagged[0]['Hgg']['Hgg']['Btag'].view(flow=True)[:] *= bscalesHJ
btagged[0]['Hgg']['Hgg']['D2'].view(flow=True)[:] *= bscalesHJ
# btagged[0]['Hgg']['Hgg']['D3'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hgg']['Hgg']['N4'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hgg']['Hgg']['U1'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hgg']['Hgg']['U2'].view(flow=True)[:] *= bscalesHbb
# btagged[0]['Hgg']['Hgg']['U3'].view(flow=True)[:] *= bscalesHbb

# %%
cr_hgg_total = not_btagged[0]['Hgg']['Hgg']['Color_Ring'][0:40:sum]
cr_hbb_total = not_btagged[0]['Hbb']['Hbb']['Color_Ring'][0:40:sum]
bcr_hgg_total = btagged[0]['Hgg']['Hgg']['Color_Ring'][0:40:sum]
bcr_hbb_total = btagged[0]['Hbb']['Hbb']['Color_Ring'][0:40:sum]

# cr_groomed_hgg_total = not_btagged[0]['Hgg']['Hgg']['Color_Ring_Groomed'][0:40:sum]
# cr_groomed_hbb_total = not_btagged[0]['Hbb']['Hbb']['Color_Ring_Groomed'][0:40:sum]
# bcr_groomed_hgg_total = btagged[0]['Hgg']['Hgg']['Color_Ring_Groomed'][0:40:sum]
# bcr_groomed_hbb_total = btagged[0]['Hbb']['Hbb']['Color_Ring_Groomed'][0:40:sum]

# crvar_hgg_total = not_btagged[0]['Hgg']['Hgg']['Color_Ring_Var'][0:40:sum]
# crvar_hbb_total = not_btagged[0]['Hbb']['Hbb']['Color_Ring_Var'][0:40:sum]
# bcrvar_hgg_total = btagged[0]['Hgg']['Hgg']['Color_Ring_Var'][0:40:sum]
# bcrvar_hbb_total = btagged[0]['Hbb']['Hbb']['Color_Ring_Var'][0:40:sum]

n2_hgg_total = not_btagged[0]['Hgg']['Hgg']['N2'][0:40:sum]
n2_hbb_total = not_btagged[0]['Hbb']['Hbb']['N2'][0:40:sum]
bn2_hgg_total = btagged[0]['Hgg']['Hgg']['N2'][0:40:sum]
bn2_hbb_total = btagged[0]['Hbb']['Hbb']['N2'][0:40:sum]

n3_hgg_total = not_btagged[0]['Hgg']['Hgg']['N3'][0:40:sum]
n3_hbb_total = not_btagged[0]['Hbb']['Hbb']['N3'][0:40:sum]
bn3_hgg_total = btagged[0]['Hgg']['Hgg']['N3'][0:40:sum]
bn3_hbb_total = btagged[0]['Hbb']['Hbb']['N3'][0:40:sum]

ncons_hgg_total = not_btagged[0]['Hgg']['Hgg']['nConstituents'][0:40:sum]
ncons_hbb_total = not_btagged[0]['Hbb']['Hbb']['nConstituents'][0:40:sum]
bncons_hgg_total = btagged[0]['Hgg']['Hgg']['nConstituents'][0:40:sum]
bncons_hbb_total = btagged[0]['Hbb']['Hbb']['nConstituents'][0:40:sum]

mass_hgg_total = not_btagged[0]['Hgg']['Hgg']['Mass'][0:40:sum]
mass_hbb_total = not_btagged[0]['Hbb']['Hbb']['Mass'][0:40:sum]
bmass_hgg_total = btagged[0]['Hgg']['Hgg']['Mass'][0:40:sum]
bmass_hbb_total = btagged[0]['Hbb']['Hbb']['Mass'][0:40:sum]

sdmass_hgg_total = not_btagged[0]['Hgg']['Hgg']['SDmass'][0:40:sum]
sdmass_hbb_total = not_btagged[0]['Hbb']['Hbb']['SDmass'][0:40:sum]
bsdmass_hgg_total = btagged[0]['Hgg']['Hgg']['SDmass'][0:40:sum]
bsdmass_hbb_total = btagged[0]['Hbb']['Hbb']['SDmass'][0:40:sum]

btag_hgg_total = not_btagged[0]['Hgg']['Hgg']['Btag'][0:40:sum]
btag_hbb_total = not_btagged[0]['Hbb']['Hbb']['Btag'][0:40:sum]
bbtag_hgg_total = btagged[0]['Hgg']['Hgg']['Btag'][0:40:sum]
bbtag_hbb_total = btagged[0]['Hbb']['Hbb']['Btag'][0:40:sum]

d2_hgg_total = not_btagged[0]['Hgg']['Hgg']['D2'][0:40:sum]
d2_hbb_total = not_btagged[0]['Hbb']['Hbb']['D2'][0:40:sum]
bd2_hgg_total = btagged[0]['Hgg']['Hgg']['D2'][0:40:sum]
bd2_hbb_total = btagged[0]['Hbb']['Hbb']['D2'][0:40:sum]

# d3_hgg_total = not_btagged[0]['Hgg']['Hgg']['D3'][0:40:sum]
# d3_hbb_total = not_btagged[0]['Hbb']['Hbb']['D3'][0:40:sum]
# bd3_hgg_total = btagged[0]['Hgg']['Hgg']['D3'][0:40:sum]
# bd3_hbb_total = btagged[0]['Hbb']['Hbb']['D3'][0:40:sum]

# n4_hgg_total = not_btagged[0]['Hgg']['Hgg']['N4'][0:40:sum]
# n4_hbb_total = not_btagged[0]['Hbb']['Hbb']['N4'][0:40:sum]
# bn4_hgg_total = btagged[0]['Hgg']['Hgg']['N4'][0:40:sum]
# bn4_hbb_total = btagged[0]['Hbb']['Hbb']['N4'][0:40:sum]

# u1_hgg_total = not_btagged[0]['Hgg']['Hgg']['U1'][0:40:sum]
# u1_hbb_total = not_btagged[0]['Hbb']['Hbb']['U1'][0:40:sum]
# bu1_hgg_total = btagged[0]['Hgg']['Hgg']['U1'][0:40:sum]
# bu1_hbb_total = btagged[0]['Hbb']['Hbb']['U1'][0:40:sum]

# u2_hgg_total = not_btagged[0]['Hgg']['Hgg']['U2'][0:40:sum]
# u2_hbb_total = not_btagged[0]['Hbb']['Hbb']['U2'][0:40:sum]
# bu2_hgg_total = btagged[0]['Hgg']['Hgg']['U2'][0:40:sum]
# bu2_hbb_total = btagged[0]['Hbb']['Hbb']['U2'][0:40:sum]

# u3_hgg_total = not_btagged[0]['Hgg']['Hgg']['U3'][0:40:sum]
# u3_hbb_total = not_btagged[0]['Hbb']['Hbb']['U3'][0:40:sum]
# bu3_hgg_total = btagged[0]['Hgg']['Hgg']['U3'][0:40:sum]
# bu3_hbb_total = btagged[0]['Hbb']['Hbb']['U3'][0:40:sum]

# %%
hgg_cr_true_positive = []
for i in range(1, 41):
    hgg_cr_true_positive.append(not_btagged[0]['Hgg']['Hgg']['Color_Ring'][0:i:sum].value/cr_hgg_total.value)
hgg_cr_true_positive.insert(0,0)
bhgg_cr_true_positive = []
for i in range(1, 41):
    bhgg_cr_true_positive.append(btagged[0]['Hgg']['Hgg']['Color_Ring'][0:i:sum].value/bcr_hgg_total.value)
bhgg_cr_true_positive.insert(0,0)

# hgg_cr_groomed_true_positive = []
# for i in range(1, 41):
#     hgg_cr_groomed_true_positive.append(not_btagged[0]['Hgg']['Hgg']['Color_Ring_Groomed'][0:i:sum].value/cr_groomed_hgg_total.value)
# hgg_cr_groomed_true_positive.insert(0,0)
# bhgg_cr_groomed_true_positive = []
# for i in range(1, 41):
#     bhgg_cr_groomed_true_positive.append(btagged[0]['Hgg']['Hgg']['Color_Ring_Groomed'][0:i:sum].value/bcr_groomed_hgg_total.value)
# bhgg_cr_groomed_true_positive.insert(0,0)

# hgg_crvar_true_positive = []
# for i in range(1, 41):
#     hgg_crvar_true_positive.append(not_btagged[0]['Hgg']['Hgg']['Color_Ring_Var'][0:i:sum].value/crvar_hgg_total.value)
# bhgg_crvar_true_positive = []
# for i in range(1, 41):
#     bhgg_crvar_true_positive.append(btagged[0]['Hgg']['Hgg']['Color_Ring_Var'][0:i:sum].value/bcrvar_hgg_total.value)
    
hgg_n2_true_positive = []
for i in range(1, 41):
    hgg_n2_true_positive.append(not_btagged[0]['Hgg']['Hgg']['N2'][0:i:sum].value/n2_hgg_total.value)
bhgg_n2_true_positive = []
for i in range(1, 41):
    bhgg_n2_true_positive.append(btagged[0]['Hgg']['Hgg']['N2'][0:i:sum].value/bn2_hgg_total.value)
    
hgg_n3_true_positive = []
for i in range(1, 41):
    hgg_n3_true_positive.append(not_btagged[0]['Hgg']['Hgg']['N3'][0:i:sum].value/n3_hgg_total.value)
bhgg_n3_true_positive = []
for i in range(1, 41):
    bhgg_n3_true_positive.append(btagged[0]['Hgg']['Hgg']['N3'][0:i:sum].value/bn3_hgg_total.value)
    
hgg_ncons_true_positive = []
for i in range(1, 41):
    hgg_ncons_true_positive.append(not_btagged[0]['Hgg']['Hgg']['nConstituents'][0:i:sum].value/ncons_hgg_total.value)
bhgg_ncons_true_positive = []
for i in range(1, 41):
    bhgg_ncons_true_positive.append(btagged[0]['Hgg']['Hgg']['nConstituents'][0:i:sum].value/bncons_hgg_total.value)
    
hgg_mass_true_positive = []
for i in range(1, 41):
    hgg_mass_true_positive.append(not_btagged[0]['Hgg']['Hgg']['Mass'][0:i:sum].value/mass_hgg_total.value)
bhgg_mass_true_positive = []
for i in range(1, 41):
    bhgg_mass_true_positive.append(btagged[0]['Hgg']['Hgg']['Mass'][0:i:sum].value/bmass_hgg_total.value)
    
hgg_sdmass_true_positive = []
for i in range(1, 41):
    hgg_sdmass_true_positive.append(not_btagged[0]['Hgg']['Hgg']['SDmass'][0:i:sum].value/sdmass_hgg_total.value)
bhgg_sdmass_true_positive = []
for i in range(1, 41):
    bhgg_sdmass_true_positive.append(btagged[0]['Hgg']['Hgg']['SDmass'][0:i:sum].value/bsdmass_hgg_total.value)
    
hgg_btag_true_positive = []
for i in range(1, 41):
    hgg_btag_true_positive.append(not_btagged[0]['Hgg']['Hgg']['Btag'][0:i:sum].value/btag_hgg_total.value)
bhgg_btag_true_positive = []
for i in range(1, 41):
    bhgg_btag_true_positive.append(btagged[0]['Hgg']['Hgg']['Btag'][0:i:sum].value/bbtag_hgg_total.value)

hgg_d2_true_positive = []
for i in range(1, 41):
    hgg_d2_true_positive.append(not_btagged[0]['Hgg']['Hgg']['D2'][0:i:sum].value/d2_hgg_total.value)
bhgg_d2_true_positive = []
for i in range(1, 41):
    bhgg_d2_true_positive.append(btagged[0]['Hgg']['Hgg']['D2'][0:i:sum].value/bd2_hgg_total.value)

hgg_d3_true_positive = []
# for i in range(1, 41):
#     hgg_d3_true_positive.append(not_btagged[0]['Hgg']['Hgg']['D3'][0:i:sum].value/d3_hgg_total.value)
# bhgg_d3_true_positive = []
# for i in range(1, 41):
#     bhgg_d3_true_positive.append(btagged[0]['Hgg']['Hgg']['D3'][0:i:sum].value/bd3_hgg_total.value)

# hgg_n4_true_positive = []
# for i in range(1, 41):
#     hgg_n4_true_positive.append(not_btagged[0]['Hgg']['Hgg']['N4'][0:i:sum].value/n4_hgg_total.value)
# bhgg_n4_true_positive = []
# for i in range(1, 41):
#     bhgg_n4_true_positive.append(btagged[0]['Hgg']['Hgg']['N4'][0:i:sum].value/bn4_hgg_total.value)

# hgg_u1_true_positive = []
# for i in range(1, 41):
#     hgg_u1_true_positive.append(not_btagged[0]['Hgg']['Hgg']['U1'][0:i:sum].value/u1_hgg_total.value)
# bhgg_u1_true_positive = []
# for i in range(1, 41):
#     bhgg_u1_true_positive.append(btagged[0]['Hgg']['Hgg']['U1'][0:i:sum].value/bu1_hgg_total.value)

# hgg_u2_true_positive = []
# for i in range(1, 41):
#     hgg_u2_true_positive.append(not_btagged[0]['Hgg']['Hgg']['U2'][0:i:sum].value/u2_hgg_total.value)
# bhgg_u2_true_positive = []
# for i in range(1, 41):
#     bhgg_u2_true_positive.append(btagged[0]['Hgg']['Hgg']['U2'][0:i:sum].value/bu2_hgg_total.value)

# hgg_u3_true_positive = []
# for i in range(1, 41):
#     hgg_u3_true_positive.append(not_btagged[0]['Hgg']['Hgg']['U3'][0:i:sum].value/u3_hgg_total.value)
# bhgg_u3_true_positive = []
# for i in range(1, 41):
#     bhgg_u3_true_positive.append(btagged[0]['Hgg']['Hgg']['U3'][0:i:sum].value/bu3_hgg_total.value)

# %%
hbb_cr_true_positive = []
for i in range(1, 41):
    hbb_cr_true_positive.append(not_btagged[0]['Hbb']['Hbb']['Color_Ring'][0:i:sum].value/cr_hbb_total.value)
hbb_cr_true_positive.insert(0,0)
bhbb_cr_true_positive = []
for i in range(1, 41):
    bhbb_cr_true_positive.append(btagged[0]['Hbb']['Hbb']['Color_Ring'][0:i:sum].value/bcr_hbb_total.value)
bhbb_cr_true_positive.insert(0,0)

# hbb_cr_groomed_true_positive = []
# for i in range(1, 41):
#     hbb_cr_groomed_true_positive.append(not_btagged[0]['Hbb']['Hbb']['Color_Ring_Groomed'][0:i:sum].value/cr_groomed_hbb_total.value)
# hbb_cr_groomed_true_positive.insert(0,0)
# bhbb_cr_groomed_true_positive = []
# for i in range(1, 41):
#     bhbb_cr_groomed_true_positive.append(btagged[0]['Hbb']['Hbb']['Color_Ring_Groomed'][0:i:sum].value/bcr_groomed_hbb_total.value)
# bhbb_cr_groomed_true_positive.insert(0,0)

# hbb_crvar_true_positive = []
# for i in range(1, 41):
#     hbb_crvar_true_positive.append(not_btagged[0]['Hbb']['Hbb']['Color_Ring_Var'][0:i:sum].value/crvar_hbb_total.value)
# bhbb_crvar_true_positive = []
# for i in range(1, 41):
#     bhbb_crvar_true_positive.append(btagged[0]['Hbb']['Hbb']['Color_Ring_Var'][0:i:sum].value/bcrvar_hbb_total.value)
    
hbb_n2_true_positive = []
for i in range(1, 41):
    hbb_n2_true_positive.append(not_btagged[0]['Hbb']['Hbb']['N2'][0:i:sum].value/n2_hbb_total.value)
bhbb_n2_true_positive = []
for i in range(1, 41):
    bhbb_n2_true_positive.append(btagged[0]['Hbb']['Hbb']['N2'][0:i:sum].value/bn2_hbb_total.value)
    
hbb_n3_true_positive = []
for i in range(1, 41):
    hbb_n3_true_positive.append(not_btagged[0]['Hbb']['Hbb']['N3'][0:i:sum].value/n3_hbb_total.value)
bhbb_n3_true_positive = []
for i in range(1, 41):
    bhbb_n3_true_positive.append(btagged[0]['Hbb']['Hbb']['N3'][0:i:sum].value/bn3_hbb_total.value)
    
hbb_ncons_true_positive = []
for i in range(1, 41):
    hbb_ncons_true_positive.append(not_btagged[0]['Hbb']['Hbb']['nConstituents'][0:i:sum].value/ncons_hbb_total.value)
bhbb_ncons_true_positive = []
for i in range(1, 41):
    bhbb_ncons_true_positive.append(btagged[0]['Hbb']['Hbb']['nConstituents'][0:i:sum].value/bncons_hbb_total.value)
    
hbb_mass_true_positive = []
for i in range(1, 41):
    hbb_mass_true_positive.append(not_btagged[0]['Hbb']['Hbb']['Mass'][0:i:sum].value/mass_hbb_total.value)
bhbb_mass_true_positive = []
for i in range(1, 41):
    bhbb_mass_true_positive.append(not_btagged[0]['Hbb']['Hbb']['Mass'][0:i:sum].value/bmass_hbb_total.value)
    
hbb_sdmass_true_positive = []
for i in range(1, 41):
    hbb_sdmass_true_positive.append(not_btagged[0]['Hbb']['Hbb']['SDmass'][0:i:sum].value/sdmass_hbb_total.value)
bhbb_sdmass_true_positive = []
for i in range(1, 41):
    bhbb_sdmass_true_positive.append(not_btagged[0]['Hbb']['Hbb']['SDmass'][0:i:sum].value/bsdmass_hbb_total.value)
    
hbb_btag_true_positive = []
for i in range(1, 41):
    hbb_btag_true_positive.append(not_btagged[0]['Hbb']['Hbb']['Btag'][0:i:sum].value/btag_hbb_total.value)
bhbb_btag_true_positive = []
for i in range(1, 41):
    bhbb_btag_true_positive.append(btagged[0]['Hbb']['Hbb']['Btag'][0:i:sum].value/bbtag_hbb_total.value)

hbb_d2_true_positive = []
for i in range(1, 41):
    hbb_d2_true_positive.append(not_btagged[0]['Hbb']['Hbb']['D2'][0:i:sum].value/d2_hbb_total.value)
bhbb_d2_true_positive = []
for i in range(1, 41):
    bhbb_d2_true_positive.append(btagged[0]['Hbb']['Hbb']['D2'][0:i:sum].value/bd2_hbb_total.value)

# hbb_d3_true_positive = []
# for i in range(1, 41):
#     hbb_d3_true_positive.append(not_btagged[0]['Hbb']['Hbb']['D3'][0:i:sum].value/d3_hbb_total.value)
# bhbb_d3_true_positive = []
# for i in range(1, 41):
#     bhbb_d3_true_positive.append(btagged[0]['Hbb']['Hbb']['D3'][0:i:sum].value/bd3_hbb_total.value)

# hbb_n4_true_positive = []
# for i in range(1, 41):
#     hbb_n4_true_positive.append(not_btagged[0]['Hbb']['Hbb']['N4'][0:i:sum].value/n4_hbb_total.value)
# bhbb_n4_true_positive = []
# for i in range(1, 41):
#     bhbb_n4_true_positive.append(btagged[0]['Hbb']['Hbb']['N4'][0:i:sum].value/bn4_hbb_total.value)

# hbb_u1_true_positive = []
# for i in range(1, 41):
#     hbb_u1_true_positive.append(not_btagged[0]['Hbb']['Hbb']['U1'][0:i:sum].value/u1_hbb_total.value)
# bhbb_u1_true_positive = []
# for i in range(1, 41):
#     bhbb_u1_true_positive.append(btagged[0]['Hbb']['Hbb']['U1'][0:i:sum].value/bu1_hbb_total.value)

# hbb_u2_true_positive = []
# for i in range(1, 41):
#     hbb_u2_true_positive.append(not_btagged[0]['Hbb']['Hbb']['U2'][0:i:sum].value/u2_hbb_total.value)
# bhbb_u2_true_positive = []
# for i in range(1, 41):
#     bhbb_u2_true_positive.append(btagged[0]['Hbb']['Hbb']['U2'][0:i:sum].value/bu2_hbb_total.value)

# hbb_u3_true_positive = []
# for i in range(1, 41):
#     hbb_u3_true_positive.append(not_btagged[0]['Hbb']['Hbb']['U3'][0:i:sum].value/u3_hbb_total.value)
# bhbb_u3_true_positive = []
# for i in range(1, 41):
#     bhbb_u3_true_positive.append(btagged[0]['Hbb']['Hbb']['U3'][0:i:sum].value/bu3_hbb_total.value)

# %%
#2017 integrated luminosity and QCD cross sections
IL = 44.99
xs_300to470 = 6833
xs_470to600 = 549.5
xs_600to800 = 156.5
xs_800to1000 = 26.22
xs_1000to1400 = 7.475
xs_1400to1800 = 0.6482
xs_1800to2400 = 0.08742
xs_2400to3200 = 0.005237
xs_3200toInf = 0.0001353

# %%
#QCD scale factors
scales300to470 = (((xs_300to470*1000)*IL)/(not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['entries']))
scales470to600 = (((xs_470to600*1000)*IL)/(not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['entries']))
scales600to800 = (((xs_600to800*1000)*IL)/(not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['entries']))
scales800to1000 = (((xs_800to1000*1000)*IL)/(not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['entries']))
scales1000to1400 = (((xs_1000to1400*1000)*IL)/(not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['entries']))
scales1400to1800 = (((xs_1400to1800*1000)*IL)/(not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['entries']))
scales1800to2400 = (((xs_1800to2400*1000)*IL)/(not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['entries']))
scales2400to3200 = (((xs_2400to3200*1000)*IL)/(not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['entries']))
scales3200toInf = (((xs_3200toInf*1000)*IL)/(not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['entries']))

bscales300to470 = (((xs_300to470*1000)*IL)/(btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['entries']))
bscales470to600 = (((xs_470to600*1000)*IL)/(btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['entries']))
bscales600to800 = (((xs_600to800*1000)*IL)/(btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['entries']))
bscales800to1000 = (((xs_800to1000*1000)*IL)/(btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['entries']))
bscales1000to1400 = (((xs_1000to1400*1000)*IL)/(btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['entries']))
bscales1400to1800 = (((xs_1400to1800*1000)*IL)/(btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['entries']))
bscales1800to2400 = (((xs_1800to2400*1000)*IL)/(btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['entries']))
bscales2400to3200 = (((xs_2400to3200*1000)*IL)/(btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['entries']))
bscales3200toInf = (((xs_3200toInf*1000)*IL)/(btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['entries']))

# %%
not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring'].view(flow=True)[:] *= scales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Groomed'].view(flow=True)[:] *= scales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Groomed'].view(flow=True)[:] *= scales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Groomed'].view(flow=True)[:] *= scales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Groomed'].view(flow=True)[:] *= scales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Groomed'].view(flow=True)[:] *= scales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Groomed'].view(flow=True)[:] *= scales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Groomed'].view(flow=True)[:] *= scales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Groomed'].view(flow=True)[:] *= scales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Groomed'].view(flow=True)[:] *= scales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Var'].view(flow=True)[:] *= scales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Var'].view(flow=True)[:] *= scales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Var'].view(flow=True)[:] *= scales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Var'].view(flow=True)[:] *= scales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Var'].view(flow=True)[:] *= scales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Var'].view(flow=True)[:] *= scales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Var'].view(flow=True)[:] *= scales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Var'].view(flow=True)[:] *= scales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Var'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N2'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N2'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N2'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N2'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N2'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N2'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N2'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N2'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N2'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N3'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N3'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N3'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N3'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N3'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N3'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N3'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N3'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N3'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['nConstituents'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['nConstituents'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['nConstituents'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['nConstituents'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['nConstituents'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['nConstituents'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['nConstituents'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['nConstituents'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['nConstituents'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Mass'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Mass'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Mass'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Mass'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Mass'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Mass'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Mass'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Mass'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Mass'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['SDmass'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['SDmass'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['SDmass'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['SDmass'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['SDmass'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['SDmass'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['SDmass'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['SDmass'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['SDmass'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Btag'].view(flow=True)[:] *= scales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Btag'].view(flow=True)[:] *= scales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Btag'].view(flow=True)[:] *= scales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Btag'].view(flow=True)[:] *= scales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Btag'].view(flow=True)[:] *= scales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Btag'].view(flow=True)[:] *= scales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Btag'].view(flow=True)[:] *= scales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Btag'].view(flow=True)[:] *= scales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Btag'].view(flow=True)[:] *= scales3200toInf

not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D2'].view(flow=True)[:] *= bscales300to470
not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D2'].view(flow=True)[:] *= bscales470to600
not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D2'].view(flow=True)[:] *= bscales600to800
not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D2'].view(flow=True)[:] *= bscales800to1000
not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D2'].view(flow=True)[:] *= bscales1000to1400
not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D2'].view(flow=True)[:] *= bscales1400to1800
not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D2'].view(flow=True)[:] *= bscales1800to2400
not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D2'].view(flow=True)[:] *= bscales2400to3200
not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D2'].view(flow=True)[:] *= bscales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D3'].view(flow=True)[:] *= bscales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D3'].view(flow=True)[:] *= bscales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D3'].view(flow=True)[:] *= bscales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D3'].view(flow=True)[:] *= bscales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D3'].view(flow=True)[:] *= bscales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D3'].view(flow=True)[:] *= bscales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D3'].view(flow=True)[:] *= bscales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D3'].view(flow=True)[:] *= bscales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D3'].view(flow=True)[:] *= bscales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N4'].view(flow=True)[:] *= bscales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N4'].view(flow=True)[:] *= bscales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N4'].view(flow=True)[:] *= bscales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N4'].view(flow=True)[:] *= bscales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N4'].view(flow=True)[:] *= bscales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N4'].view(flow=True)[:] *= bscales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N4'].view(flow=True)[:] *= bscales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N4'].view(flow=True)[:] *= bscales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N4'].view(flow=True)[:] *= bscales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U1'].view(flow=True)[:] *= bscales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U1'].view(flow=True)[:] *= bscales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U1'].view(flow=True)[:] *= bscales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U1'].view(flow=True)[:] *= bscales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U1'].view(flow=True)[:] *= bscales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U1'].view(flow=True)[:] *= bscales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U1'].view(flow=True)[:] *= bscales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U1'].view(flow=True)[:] *= bscales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U1'].view(flow=True)[:] *= bscales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U2'].view(flow=True)[:] *= bscales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U2'].view(flow=True)[:] *= bscales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U2'].view(flow=True)[:] *= bscales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U2'].view(flow=True)[:] *= bscales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U2'].view(flow=True)[:] *= bscales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U2'].view(flow=True)[:] *= bscales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U2'].view(flow=True)[:] *= bscales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U2'].view(flow=True)[:] *= bscales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U2'].view(flow=True)[:] *= bscales3200toInf

# not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U3'].view(flow=True)[:] *= bscales300to470
# not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U3'].view(flow=True)[:] *= bscales470to600
# not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U3'].view(flow=True)[:] *= bscales600to800
# not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U3'].view(flow=True)[:] *= bscales800to1000
# not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U3'].view(flow=True)[:] *= bscales1000to1400
# not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U3'].view(flow=True)[:] *= bscales1400to1800
# not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U3'].view(flow=True)[:] *= bscales1800to2400
# not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U3'].view(flow=True)[:] *= bscales2400to3200
# not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U3'].view(flow=True)[:] *= bscales3200toInf

# %%
btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Groomed'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Var'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Var'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Var'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Var'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Var'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Var'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Var'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Var'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Var'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N2'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N2'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N2'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N2'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N2'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N2'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N2'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N2'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N2'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N3'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N3'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N3'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N3'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N3'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N3'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N3'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N3'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N3'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['nConstituents'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['nConstituents'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['nConstituents'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['nConstituents'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['nConstituents'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['nConstituents'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['nConstituents'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['nConstituents'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['nConstituents'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Mass'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Mass'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Mass'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Mass'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Mass'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Mass'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Mass'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Mass'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Mass'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['SDmass'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['SDmass'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['SDmass'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['SDmass'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['SDmass'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['SDmass'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['SDmass'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['SDmass'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['SDmass'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Btag'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Btag'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Btag'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Btag'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Btag'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Btag'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Btag'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Btag'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Btag'].view(flow=True)[:] *= bscales3200toInf

btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D2'].view(flow=True)[:] *= bscales300to470
btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D2'].view(flow=True)[:] *= bscales470to600
btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D2'].view(flow=True)[:] *= bscales600to800
btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D2'].view(flow=True)[:] *= bscales800to1000
btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D2'].view(flow=True)[:] *= bscales1000to1400
btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D2'].view(flow=True)[:] *= bscales1400to1800
btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D2'].view(flow=True)[:] *= bscales1800to2400
btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D2'].view(flow=True)[:] *= bscales2400to3200
btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D2'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D3'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D3'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D3'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D3'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D3'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D3'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D3'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D3'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D3'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N4'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N4'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N4'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N4'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N4'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N4'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N4'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N4'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N4'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U1'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U1'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U1'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U1'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U1'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U1'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U1'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U1'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U1'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U2'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U2'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U2'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U2'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U2'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U2'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U2'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U2'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U2'].view(flow=True)[:] *= bscales3200toInf

# btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U3'].view(flow=True)[:] *= bscales300to470
# btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U3'].view(flow=True)[:] *= bscales470to600
# btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U3'].view(flow=True)[:] *= bscales600to800
# btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U3'].view(flow=True)[:] *= bscales800to1000
# btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U3'].view(flow=True)[:] *= bscales1000to1400
# btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U3'].view(flow=True)[:] *= bscales1400to1800
# btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U3'].view(flow=True)[:] *= bscales1800to2400
# btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U3'].view(flow=True)[:] *= bscales2400to3200
# btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U3'].view(flow=True)[:] *= bscales3200toInf

# %%
qcd_cr = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring'])

# qcd_cr_groomed = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Groomed']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Groomed'])

# qcd_crvar = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Var']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Var'])

qcd_n2 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N2']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N2']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N2']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N2']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N2']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N2']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N2']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N2']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N2'])

qcd_n3 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N3']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N3']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N3']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N3']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N3']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N3']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N3']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N3']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N3'])

qcd_ncons = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['nConstituents']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['nConstituents']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['nConstituents']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['nConstituents']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['nConstituents']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['nConstituents']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['nConstituents']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['nConstituents']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['nConstituents'])

qcd_mass = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Mass']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Mass']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Mass']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Mass']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Mass']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Mass']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Mass']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Mass']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Mass'])

qcd_sdmass = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['SDmass']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['SDmass']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['SDmass']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['SDmass']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['SDmass']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['SDmass']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['SDmass']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['SDmass']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['SDmass'])

qcd_btag = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Btag']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Btag']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Btag']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Btag']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Btag']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Btag']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Btag']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Btag']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Btag'])

qcd_d2 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D2']+
        not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D2']+
        not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D2']+
        not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D2']+
        not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D2']+
        not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D2']+
        not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D2']+
        not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D2']+
        not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D2'])

# qcd_d3 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D3']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D3']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D3']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D3']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D3']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D3']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D3']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D3']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D3'])

# qcd_n4 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N4']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N4']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N4']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N4']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N4']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N4']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N4']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N4']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N4'])

# qcd_u1 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U1']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U1']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U1']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U1']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U1']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U1']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U1']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U1']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U1'])

# qcd_u2 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U2']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U2']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U2']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U2']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U2']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U2']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U2']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U2']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U2'])

# qcd_u3 = (not_btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U3']+
#         not_btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U3']+
#         not_btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U3']+
#         not_btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U3']+
#         not_btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U3']+
#         not_btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U3']+
#         not_btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U3']+
#         not_btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U3']+
#         not_btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U3'])

# %%
bqcd_cr = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring'])

# bqcd_cr_groomed = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Groomed']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Groomed'])

# bqcd_crvar = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Color_Ring_Var']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Color_Ring_Var'])


bqcd_n2 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N2']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N2']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N2']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N2']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N2']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N2']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N2']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N2']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N2'])

bqcd_n3 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N3']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N3']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N3']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N3']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N3']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N3']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N3']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N3']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N3'])

bqcd_ncons = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['nConstituents']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['nConstituents']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['nConstituents']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['nConstituents']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['nConstituents']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['nConstituents']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['nConstituents']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['nConstituents']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['nConstituents'])

bqcd_mass = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Mass']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Mass']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Mass']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Mass']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Mass']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Mass']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Mass']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Mass']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Mass'])

bqcd_sdmass = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['SDmass']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['SDmass']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['SDmass']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['SDmass']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['SDmass']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['SDmass']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['SDmass']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['SDmass']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['SDmass'])

bqcd_btag = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['Btag']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['Btag']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['Btag']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['Btag']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['Btag']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['Btag']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['Btag']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['Btag']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['Btag'])

bqcd_d2 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D2']+
        btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D2']+
        btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D2']+
        btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D2']+
        btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D2']+
        btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D2']+
        btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D2']+
        btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D2']+
        btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D2'])

# bqcd_d3 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D3']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D3']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D3']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D3']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D3']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D3']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D3']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D3']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D3'])

# bqcd_n4 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N4']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N4']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N4']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N4']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N4']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N4']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N4']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N4']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N4'])

# bqcd_u1 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U1']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U1']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U1']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U1']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U1']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U1']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U1']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U1']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U1'])

# bqcd_u2 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U2']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U2']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U2']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U2']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U2']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U2']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U2']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U2']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U2'])

# bqcd_u3 = (btagged[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['U3']+
#         btagged[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['U3']+
#         btagged[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['U3']+
#         btagged[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['U3']+
#         btagged[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['U3']+
#         btagged[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['U3']+
#         btagged[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['U3']+
#         btagged[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['U3']+
#         btagged[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['U3'])

# %%
cr_bckgrd_total = qcd_cr[0:40:sum]
# cr_groomed_bckgrd_total = qcd_cr_groomed[0:40:sum]
# crvar_bckgrd_total = qcd_crvar[0:40:sum]
n2_bckgrd_total = qcd_n2[0:40:sum]
n3_bckgrd_total = qcd_n3[0:40:sum]
ncons_bckgrd_total = qcd_ncons[0:40:sum]
mass_bckgrd_total = qcd_mass[0:40:sum]
sdmass_bckgrd_total = qcd_sdmass[0:40:sum]
btag_bckgrd_total = qcd_btag[0:40:sum]
d2_bckgrd_total = qcd_d2[0:40:sum]
# d3_bckgrd_total = qcd_d3[0:40:sum]
# n4_bckgrd_total = qcd_n4[0:40:sum]
# u1_bckgrd_total = qcd_u1[0:40:sum]
# u2_bckgrd_total = qcd_u2[0:40:sum]
# u3_bckgrd_total = qcd_u3[0:40:sum]

bcr_bckgrd_total = bqcd_cr[0:40:sum]
# bcr_groomed_bckgrd_total = bqcd_cr_groomed[0:40:sum]
# bcrvar_bckgrd_total = bqcd_crvar[0:40:sum]
bn2_bckgrd_total = bqcd_n2[0:40:sum]
bn3_bckgrd_total = bqcd_n3[0:40:sum]
bncons_bckgrd_total = bqcd_ncons[0:40:sum]
bmass_bckgrd_total = bqcd_mass[0:40:sum]
bsdmass_bckgrd_total = bqcd_sdmass[0:40:sum]
bbtag_bckgrd_total = bqcd_btag[0:40:sum]
bd2_bckgrd_total = bqcd_d2[0:40:sum]
# bd3_bckgrd_total = bqcd_d3[0:40:sum]
# bn4_bckgrd_total = bqcd_n4[0:40:sum]
# bu1_bckgrd_total = bqcd_u1[0:40:sum]
# bu2_bckgrd_total = bqcd_u2[0:40:sum]
# bu3_bckgrd_total = bqcd_u3[0:40:sum]

# %%
cr_false_positive = []
for i in range(1, 41):
    cr_false_positive.append(qcd_cr[0:i:sum].value/cr_bckgrd_total.value)
cr_false_positive.insert(0,0)

bcr_false_positive = []
for i in range(1, 41):
    bcr_false_positive.append(bqcd_cr[0:i:sum].value/bcr_bckgrd_total.value)
bcr_false_positive.insert(0,0)

# cr_groomed_false_positive = []
# for i in range(1, 41):
#     cr_groomed_false_positive.append(qcd_cr_groomed[0:i:sum].value/cr_groomed_bckgrd_total.value)
# cr_groomed_false_positive.insert(0,0)
# bcr_groomed_false_positive = []
# for i in range(1, 41):
#     bcr_groomed_false_positive.append(bqcd_cr_groomed[0:i:sum].value/bcr_groomed_bckgrd_total.value)
# bcr_groomed_false_positive.insert(0,0)

# crvar_false_positive = []
# for i in range(1, 41):
#     crvar_false_positive.append(qcd_crvar[0:i:sum].value/crvar_bckgrd_total.value)
# bcrvar_false_positive = []
# for i in range(1, 41):
#     bcrvar_false_positive.append(bqcd_crvar[0:i:sum].value/bcrvar_bckgrd_total.value)
    
n2_false_positive = []
for i in range(1, 41):
    n2_false_positive.append(qcd_n2[0:i:sum].value/n2_bckgrd_total.value)
bn2_false_positive = []
for i in range(1, 41):
    bn2_false_positive.append(bqcd_n2[0:i:sum].value/bn2_bckgrd_total.value)
    
n3_false_positive = []
for i in range(1, 41):
    n3_false_positive.append(qcd_n3[0:i:sum].value/n3_bckgrd_total.value)
bn3_false_positive = []
for i in range(1, 41):
    bn3_false_positive.append(bqcd_n3[0:i:sum].value/bn3_bckgrd_total.value)
    
ncons_false_positive = []
for i in range(1, 41):
    ncons_false_positive.append(qcd_ncons[0:i:sum].value/ncons_bckgrd_total.value)
bncons_false_positive = []
for i in range(1, 41):
    bncons_false_positive.append(bqcd_ncons[0:i:sum].value/bncons_bckgrd_total.value)
    
mass_false_positive = []
for i in range(1, 41):
    mass_false_positive.append(qcd_mass[0:i:sum].value/mass_bckgrd_total.value)
bmass_false_positive = []
for i in range(1, 41):
    bmass_false_positive.append(bqcd_mass[0:i:sum].value/bmass_bckgrd_total.value)
    
sdmass_false_positive = []
for i in range(1, 41):
    sdmass_false_positive.append(qcd_sdmass[0:i:sum].value/sdmass_bckgrd_total.value)
bsdmass_false_positive = []
for i in range(1, 41):
    bsdmass_false_positive.append(bqcd_sdmass[0:i:sum].value/bsdmass_bckgrd_total.value)
    
btag_false_positive = []
for i in range(1, 41):
    btag_false_positive.append(qcd_btag[0:i:sum].value/btag_bckgrd_total.value)
bbtag_false_positive = []
for i in range(1, 41):
    bbtag_false_positive.append(bqcd_btag[0:i:sum].value/bbtag_bckgrd_total.value)

d2_false_positive = []
for i in range(1, 41):
    d2_false_positive.append(qcd_d2[0:i:sum].value/d2_bckgrd_total.value)
bd2_false_positive = []
for i in range(1, 41):
    bd2_false_positive.append(bqcd_d2[0:i:sum].value/bd2_bckgrd_total.value)

# d3_false_positive = []
# for i in range(1, 41):
#     d3_false_positive.append(qcd_d3[0:i:sum].value/d3_bckgrd_total.value)
# bd3_false_positive = []
# for i in range(1, 41):
#     bd3_false_positive.append(bqcd_d3[0:i:sum].value/bd3_bckgrd_total.value)

# n4_false_positive = []
# for i in range(1, 41):
#     n4_false_positive.append(qcd_n4[0:i:sum].value/n4_bckgrd_total.value)
# bn4_false_positive = []
# for i in range(1, 41):
#     bn4_false_positive.append(bqcd_n4[0:i:sum].value/bn4_bckgrd_total.value)

# u1_false_positive = []
# for i in range(1, 41):
#     u1_false_positive.append(qcd_u1[0:i:sum].value/u1_bckgrd_total.value)
# bu1_false_positive = []
# for i in range(1, 41):
#     bu1_false_positive.append(bqcd_u1[0:i:sum].value/bu1_bckgrd_total.value)

# u2_false_positive = []
# for i in range(1, 41):
#     u2_false_positive.append(qcd_u2[0:i:sum].value/u2_bckgrd_total.value)
# bu2_false_positive = []
# for i in range(1, 41):
#     bu2_false_positive.append(bqcd_u2[0:i:sum].value/bu2_bckgrd_total.value)

# u3_false_positive = []
# for i in range(1, 41):
#     u3_false_positive.append(qcd_u3[0:i:sum].value/u3_bckgrd_total.value)
# bu3_false_positive = []
# for i in range(1, 41):
#     bu3_false_positive.append(bqcd_u3[0:i:sum].value/bu3_bckgrd_total.value)

# %%
fig, ax = plt.subplots()
# ax.plot(hgg_cr_true_positive, cr_false_positive, linewidth=2.0, label='Hgg Color Ring')
# ax.plot(hbb_cr_true_positive, cr_false_positive, linewidth=2.0, label='Hbb Color Ring')
# ax.plot(hgg_cr_true_positive, cr_false_positive, linewidth=2.0, label='Hgg Color Ring')
ax.plot(hgg_d2_true_positive, d2_false_positive, linewidth=2.0, label='D2')
ax.plot(hgg_n3_true_positive, n3_false_positive, linewidth=2.0, label='N3')
#ax.plot(bhbb_ncons_true_positive, bncons_false_positive, linewidth=2.0, label='Btagged Hbb nConstituents')
plt.xlabel("True Positive")
plt.ylabel("False Positive")
plt.title("Btagged Hbb D2 v N3")
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend()

# %%
fig, ax = plt.subplots()
(not_btagged[0]['Hgg']['Hgg']['nConstituents']).plot1d(ax=ax, label='Hgg', density=True)
qcd_ncons.plot1d(ax=ax, label='QCD', density=True)
ax.set_title('Hgg nConstituents')
plt.legend()
#plt.yscale('log')
#plt.xscale('log')
#plt.xlim(0,3)

# %%
#print(str(not_btagged[0]['Hbb']['Hbb']['Color_Ring']))
#print(str(qcd_cr_groomed))

# %%
fig, ax = plt.subplots()
#(not_btagged[0]['Hbb']['Hbb']['Btag']).plot1d(ax=ax, label='hbb', density=True)
qcd_btag.plot1d(ax=ax, label='qcd', density=True)
ax.set_title('Btag Values')
plt.legend()
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
fig, ax = plt.subplots()
(not_btagged[0]['Hbb']['Hbb']['Btag']).plot1d(ax=ax, label='Hbb', density=False)
#qcd_btag.plot1d(ax=ax, label='qcd', density=True)
ax.set_title('Hbb Btag Values')
plt.legend()
#plt.ylim(0,5)
