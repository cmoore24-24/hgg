# %%
import numpy as np
import awkward as ak
import warnings
import matplotlib.pyplot as plt
import hist
import math
import os
import json
import gc
import dask_awkward as dak

# %%
warnings.filterwarnings('ignore', 'invalid value')
warnings.filterwarnings('ignore', 'divide by')
warnings.filterwarnings('ignore', 'overflow encountered')
warnings.filterwarnings('ignore', 'Conversion of an array')

# %%
path = '/scratch365/cmoore24/training/hgg/batch2024/ml_results_checking'
with open('../../event_totals.json', 'r') as f:
    totals = json.load(f)

# %%
with open(f'{path}/my_xsecs.json', 'r') as f:
    xsecs = json.load(f)

# %%
xsecs2 = {}
for i in xsecs:
    if type(xsecs[i]) == dict:
        for j in xsecs[i]:
            xsecs2[j] = xsecs[i][j]
    else:
        xsecs2[i] = xsecs[i]
xsecs = xsecs2

# %%
totals2 = {}
for i in totals:
    if type(totals[i]) == dict:
        for j in totals[i]:
            totals2[f'{i}_{j}'] = totals[i][j]
    else:
        totals2[i] = totals[i]
totals = totals2

# %%
def read_files(input_path):
    if ('.parquet' in os.listdir(input_path)[0]):
        output = ak.from_parquet(f'{input_path}/new*', columns=columns)
    else:
        output = {}
        for i in os.listdir(input_path):
            if ('flat400' not in i):
                output[i] = ak.from_parquet(f'{input_path}/{i}/new*', columns=columns)
            else:
                continue
    return output

# %%
totals['ww'] = totals['diboson_ww']
totals['wz'] = totals['diboson_wz']
totals['zz'] = totals['diboson_zz']

# %%
region = 'nolepton'
path = '/project01/ndcms/cmoore24/skims/full_skims'

# %%
def add_ratio(ratio, dataframe):
    dash = ratio.find('/')
    asterisk = ratio.find('*')
    numerator = ratio[:dash]
    denominator = ratio[dash+1:asterisk]
    exponent = float(ratio[asterisk+2:])
    num_ecf = dataframe[numerator]
    den_ecf = dataframe[denominator]
    ecf_ratio = (num_ecf / (den_ecf**exponent))   
    return ecf_ratio

# %%
def get_num_den(ratio):
    dash = ratio.find('/')
    asterisk = ratio.find('*')
    numerator = ratio[:dash]
    denominator = ratio[dash+1:asterisk]  
    return (numerator, denominator)

# %%
def firsts(mc):
    for i in mc:
        if type(mc[i]) == dict:
            for j in mc[i]:
                for k in mc[i][j].fields:
                    if 'event' in k:
                        continue
                    else:
                        try:
                            mc[i][j][k] = ak.firsts(mc[i][j][k])
                        except:
                            continue
        else:
            for j in mc[i].fields:
                if 'event' in j:
                    continue
                else:
                    try:
                        mc[i][j] = ak.firsts(mc[i][j])
                    except:
                        continue
    return mc

# %%
ecf_list = dak.from_parquet('/project01/ndcms/cmoore24/skims/full_skims/nolepton/mc/hgg/new*').groomed_ecfs.fields

# %%
ratios = []
for i in range(len(ecf_list)):
    if ecf_list[i][2] == 'e':
        n1 = int(ecf_list[i][3])
        a = int(ecf_list[i][:2])
    else:
        n1 = int(ecf_list[i][2])
        a = int(ecf_list[i][0])
    for j in range(len(ecf_list)):
        if ecf_list[i] == ecf_list[j]:
            continue
        if ecf_list[j][2] == 'e':
            n2 = int(ecf_list[j][3])
            b = int(ecf_list[j][:2])
        else:
            n2 = int(ecf_list[j][2])
            b = int(ecf_list[j][0])
        if n1 < n2:
            continue
        else:
            beta1 = float(ecf_list[i][-2:])
            beta2 = float(ecf_list[j][-2:])
            exponent = (a * beta1) / (b * beta2)
            ratios.append(f'{ecf_list[i]}/{ecf_list[j]}**{exponent}')

# %%
upper = 1200
lower = 500
IL = 44.99

# %%
def ecf_hist(dataset, ecf_min, ecf_max, bins):
    make_hist = hist.Hist.new.Reg(bins, ecf_min, ecf_max, name='ECF', label='MC ECF').Weight()
    make_hist.fill(ECF=dataset)
    return make_hist

# %%
# ecfs_ks = {}
# with open('groomed_ratio_ks.json','w') as f:
#     json.dump(ecfs_ks, f)

# %%
with open('groomed_ratio_ks.json','r') as f:
    ecf_ks = json.load(f)
print(len(ecf_ks))

for k in range(len(ecf_ks), len(ratios)):

    numerator, denominator = get_num_den(ratios[k])
    
    columns=['goodjets.msoftdrop', 'goodjets.pt', ("groomed_ecfs", f'{numerator}'), ("groomed_ecfs", f'{denominator}')]
    mc = read_files(f'{path}/{region}/mc')
    mc['ww'] = mc['diboson_ww']
    mc['wz'] = mc['diboson_wz']
    mc['zz'] = mc['diboson_zz']
    del(mc['diboson_ww'])
    del(mc['diboson_wz'])
    del(mc['diboson_zz'])
    mc = firsts(mc)
    data = read_files(f'{path}/{region}/data')
    data = firsts(data)

    for i in xsecs:
        if type(mc[i]) == dict:
            for j in mc[i]:
                mask = ((mc[i][j].goodjets.pt >= lower) & (mc[i][j].goodjets.pt <= upper))
                mc[i][j] = mc[i][j][mask]
        else:
            mask = ((mc[i].goodjets.pt >= lower) & (mc[i].goodjets.pt <= upper))
            mc[i] = mc[i][mask]

    for i in data:
        if type(data[i]) == dict:
            for j in data[i]:
                mask = ((data[i][j].goodjets.pt >= lower) & (data[i][j].goodjets.pt <= upper))
                data[i][j] = data[i][j][mask]
        else:
            mask = ((data[i].goodjets.pt >= lower) & (data[i].goodjets.pt <= upper))
            data[i] = data[i][mask]

    data_s = {}
    for i in data:
        if "Jet" in i:
            data_s[i] = data[i]  
    data_arr = ak.concatenate([data[i] for i in data_s])

    data_ratio = add_ratio(ratios[k], data_arr.groomed_ecfs)

    ratio_max = ak.max(data_ratio)
    ratio_min = ak.min(data_ratio)

    data_hist = hist.Hist.new.Reg(40, ratio_min, ratio_max, name='Ratio', label='Data Ratio').Weight()
    data_hist.fill(Ratio=data_ratio)

    mc2 = {}
    for i in xsecs:
        if type(mc[i]) == dict:
            for j in mc[i]:
                mc2[j] = mc[i][j]
        else:
            mc2[i] = mc[i]
    mc = mc2    

    mc_ratios = {}
    for i in mc:
        if type(mc[i]) == dict:
            for j in mc[i]:
                mc_ratios[j] = add_ratio(ratios[k], mc[i][j].groomed_ecfs)
        else:
            mc_ratios[i] = add_ratio(ratios[k], mc[i].groomed_ecfs)

    hists = {}
    for i in mc:
        if type(mc[i]) == dict:
            hists[i] = {}
            for j in mc[i]:
                hists[i][j] = ecf_hist(mc_ratios[i][j], ratio_min, ratio_max, 40)
        else:
            hists[i] = ecf_hist(mc_ratios[i], ratio_min, ratio_max, 40)

    scaleHgg = ((IL*(xsecs['hgg']*1000)*0.0817)/(totals['hgg']))
    hists['hgg'].view(flow=True)[:] *= scaleHgg
    
    scaleHbb = ((IL*(xsecs['hbb']*1000)*0.581)/(totals['hbb']))
    hists['hbb'].view(flow=True)[:] *= scaleHbb

    for i in mc:
        if (i == 'hgg') or (i == 'hbb'):
            continue
        else:
            scale = ((IL*(xsecs[i]*1000))/(totals[i]))
            hists[i].view(flow=True)[:] *= scale

    mc_hist = sum(hists[i] for i in hists)

    mc_values, mc_bins = mc_hist.to_numpy()
    data_values, data_bins = data_hist.to_numpy()
    mc_density = mc_values / mc_values.sum()
    data_density = data_values / data_values.sum()
    mc_cdf = np.cumsum(mc_density)
    data_cdf = np.cumsum(data_density)
    ks_statistic = np.max(np.abs(mc_cdf - data_cdf))
    try:
        adjusted = -math.log10(ks_statistic)

        if adjusted >= 3:
            ratio_max = np.nanpercentile(np.array(data_ratio), 95)
            ratio_min = ak.min(data_ratio)
        
            data_hist = hist.Hist.new.Reg(40, ratio_min, ratio_max, name='Ratio', label='Data Ratio').Weight()
            data_hist.fill(Ratio=data_ratio)

            hists = {}
            for i in mc:
                if type(mc[i]) == dict:
                    hists[i] = {}
                    for j in mc[i]:
                        hists[i][j] = ecf_hist(mc_ratios[i][j], ratio_min, ratio_max, 40)
                else:
                    hists[i] = ecf_hist(mc_ratios[i], ratio_min, ratio_max, 40)

            scaleHgg = ((IL*(xsecs['hgg']*1000)*0.0817)/(totals['hgg']))
            hists['hgg'].view(flow=True)[:] *= scaleHgg
            
            scaleHbb = ((IL*(xsecs['hbb']*1000)*0.581)/(totals['hbb']))
            hists['hbb'].view(flow=True)[:] *= scaleHbb
        
            for i in mc:
                if (i == 'hgg') or (i == 'hbb'):
                    continue
                else:
                    scale = ((IL*(xsecs[i]*1000))/(totals[i]))
                    hists[i].view(flow=True)[:] *= scale
        
            mc_hist = sum(hists[i] for i in hists)
        
            mc_values, mc_bins = mc_hist.to_numpy()
            data_values, data_bins = data_hist.to_numpy()
            mc_density = mc_values / mc_values.sum()
            data_density = data_values / data_values.sum()
            mc_cdf = np.cumsum(mc_density)
            data_cdf = np.cumsum(data_density)
            ks_statistic = np.max(np.abs(mc_cdf - data_cdf))
            adjusted = -math.log10(ks_statistic)

            with open('groomed_ratio_ks.json','r') as f:
                ecf_ks = json.load(f)
        
            ecf_ks[ratios[k]] = adjusted
        
            with open('groomed_ratio_ks.json','w') as f:
                json.dump(ecf_ks, f)

        else:
            with open('groomed_ratio_ks.json','r') as f:
                ecf_ks = json.load(f)
        
            ecf_ks[ratios[k]] = adjusted
        
            with open('groomed_ratio_ks.json','w') as f:
                json.dump(ecf_ks, f)
    except:
        with open('groomed_ratio_ks.json','r') as f:
            ecf_ks = json.load(f)
    
        ecf_ks[ratios[k]] = None
    
        with open('groomed_ratio_ks.json','w') as f:
            json.dump(ecf_ks, f)

    #print(f'{var} is done')
    gc.collect()
    if k % 100 == 0:
        print(k)
# Out:
# 734
# 800
# 900
# 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 43
#      41     if "Jet" in i:
#      42         data_s[i] = data[i]
# ---> 43 data_arr = ak.concatenate([data[i] for i in data_s])
#      45 data_ratio = add_ratio(ratios[k], data_arr.groomed_ecfs)
#      47 ratio_max = ak.max(data_ratio)
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/operations/ak_concatenate.py:72, in concatenate(arrays, axis, mergebool, highlevel, behavior, attrs)
#      69     yield arrays
#      71 # Implementation
# ---> 72 return _impl(arrays, axis, mergebool, highlevel, behavior, attrs)
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/operations/ak_concatenate.py:176, in _impl(arrays, axis, mergebool, highlevel, behavior, attrs)
#     173     else:
#     174         batches.append([x])
# --> 176 contents = [ak._do.mergemany(b) for b in batches]
#     177 if len(contents) > 1:
#     178     out = _merge_as_union(contents)
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/operations/ak_concatenate.py:176, in <listcomp>(.0)
#     173     else:
#     174         batches.append([x])
# --> 176 contents = [ak._do.mergemany(b) for b in batches]
#     177 if len(contents) > 1:
#     178     out = _merge_as_union(contents)
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/_do.py:218, in mergemany(contents)
#     216 def mergemany(contents: list[Content]) -> Content:
#     217     assert len(contents) != 0
# --> 218     return contents[0]._mergemany(contents[1:])
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/contents/indexedoptionarray.py:817, in IndexedOptionArray._mergemany(self, others)
#     814             del parameters["__array__"]
#     816 tail_contents = contents[1:]
# --> 817 nextcontent = contents[0]._mergemany(tail_contents)
#     818 next = ak.contents.IndexedOptionArray(
#     819     nextindex, nextcontent, parameters=parameters
#     820 )
#     822 # FIXME: support categorical merging?
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/contents/recordarray.py:745, in RecordArray._mergemany(self, others)
#     743 minlength = ak._util.UNSET
#     744 for forfield in for_each_field:
# --> 745     merged = forfield[0]._mergemany(forfield[1:])
#     747     nextcontents.append(merged)
#     749     if minlength is ak._util.UNSET or (
#     750         not (merged.length is unknown_length or minlength is unknown_length)
#     751         and merged.length < minlength
#     752     ):
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/contents/indexedoptionarray.py:764, in IndexedOptionArray._mergemany(self, others)
#     759     array = array.to_IndexedOptionArray64()
#     761 if isinstance(
#     762     array, (ak.contents.IndexedOptionArray, ak.contents.IndexedArray)
#     763 ):
# --> 764     array = array._trim()  # see: #3185 and #3119
#     765     # If we're merging an option, then merge parameters before pulling out `content`
#     766     parameters = parameters_intersect(parameters, array._parameters)
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/contents/indexedoptionarray.py:1788, in IndexedOptionArray._trim(self)
#    1785     return self
#    1787 min_idx = nplike.min(idx_buf[only_positive])
# -> 1788 max_idx = nplike.max(idx_buf[only_positive])
#    1789 idx_buf[only_positive] -= min_idx
#    1790 index = Index(idx_buf)
#
# File ~/miniconda3/envs/coffea/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:624, in ArrayModuleNumpyLike.max(self, x, axis, keepdims, maybe_out)
#     621     assert not isinstance(x, PlaceholderArray)
#     622     return self._module.min(x, axis=axis, keepdims=keepdims, out=maybe_out)
# --> 624 def max(
#     625     self,
#     626     x: ArrayLikeT,
#     627     *,
#     628     axis: ShapeItem | tuple[ShapeItem, ...] | None = None,
#     629     keepdims: bool = False,
#     630     maybe_out: ArrayLikeT | None = None,
#     631 ) -> ArrayLikeT:
#     632     assert not isinstance(x, PlaceholderArray)
#     633     return self._module.max(x, axis=axis, keepdims=keepdims, out=maybe_out)
#
# KeyboardInterrupt:

# %%
ks_statistic

# %%
k

# %%
#GO THROUGH THE PASSING ONES AGAIN WITH 99% AS THE REQUIREMENT
