# %%
import numpy as np
import pandas as pd
import uproot
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#!pip install mplhep
#!pip install lz4 xxhash
import mplhep as hep
plt.style.use(hep.style.ROOT)

import matplotlib
matplotlib.rcParams['figure.dpi'] = 96

# %%
def load_files(filepaths, treename='Events', filter_name=None, selection=None):
    import glob
    dfs = []
    if not isinstance(filepaths, (list, tuple)):
        filepaths = [filepaths]
    filepaths = sum([glob.glob(fp) for fp in filepaths], [])
    for fp in filepaths:
        df = uproot.open(fp)[treename].arrays(library='pd', filter_name=filter_name)
        if selection is not None:
            df = df.query(selection)
        dfs.append(df)
    return pd.concat(dfs)

# %%
def bkg_rej(tpr, fpr, eff=0.5):
    idx = next(idx for idx, v in enumerate(tpr) if v>eff)
#     print('tpr=%.3f, fpr=%.6f, 1/fpr=%.2f'%(tpr[idx], fpr[idx], 1/fpr[idx]))
    rej = 1/fpr[idx]
    return rej

# %%
def plot(comp_list, title='ROC Curve', savename='testfig.png', comp_text='', eff_wps=[0.5,]):
    
    colours = {
        "Xbb vs QCD" : u'#1f77b4',
#        "b vs g" : u'#ff7f0e',
        "Xcc vs QCD" : u'#2ca02c',
#        "c vs g" : u'#d62728',
        "Xqq vs QCD" : u'#9467bd',
        "2prong vs QCD" : u'#ff7f0e',
#        "b vs c" : u'#ff7f0e'
    }
    debug = True
    
    aucs = {}
    idx = 0
    f, ax = plt.subplots()


    for name, cfg in comp_list.items():
        if debug: print(name)
        if debug: print(cfg)
        bkgrejs = {}
        if len(cfg['label']) == 6:
            sig = cfg['label'][0]
            bkgBB = cfg['label'][1]
            bkgCC = cfg['label'][2]
            bkgB = cfg['label'][3]
            bkgC = cfg['label'][4]
            bkgOthers = cfg['label'][5]
            sel = f"{cfg.get('selection')} & ({sig}==1 | {bkgBB}==1 | {bkgCC}==1 | {bkgB}==1 | {bkgC}==1 | {bkgOthers}==1)"
        else:
            sigBB = cfg['label'][0]
            sigCC = cfg['label'][1]
            sigQQ = cfg['label'][2]
            bkgBB = cfg['label'][3]
            bkgCC = cfg['label'][4]
            bkgB = cfg['label'][5]
            bkgC = cfg['label'][6]
            bkgOthers = cfg['label'][7]
            sel = f"{cfg.get('selection')} & ({sigBB}==1 | {sigCC}==1 | {sigQQ}==1 | {bkgBB}==1 | {bkgCC}==1 | {bkgB}==1 | {bkgC}==1 | {bkgOthers}==1)"

        df = load_files(cfg['filepath'], treename=cfg.get('treename', 'Events'), 
                        filter_name=cfg.get('filter_name'), selection=sel)
        if debug: print(name, cfg['score'], sel, len(df), sep=",")

        # if math.isnan(df.eval(cfg['score'])):
        #     print("Debugging, score divide by 0")
        #     cfg['score'] = '0'


        if len(cfg['label']) == 6:
            y_true = df[sig].values
        else:
            y_true = df[sigBB].values | df[sigCC].values | df[sigQQ].values
            print("sigBB:")
            print(df[sigBB].values)
            print("sigCC:")
            print(df[sigCC].values)
            print("sigQQ:")
            print(df[sigQQ].values)
            print("y_true:")
            print(y_true)
        # y_true = df[sig].values

        y_pred = df.eval(cfg['score'])
        print("y_pred:")
        print(y_pred)
        print("y_true:")
        print(y_true)

        # Debugging NaN values
        # print("len(y_truth)="+str(len(y_true)))
        # print("len(y_pred)="+str(len(y_pred)))
        
        y_pred[np.isnan(y_pred)] = 0

        fpr, tpr, thresholds = roc_curve(y_true, y_pred)
        auc = roc_auc_score(y_true, y_pred)
        aucs[idx] = auc
        idx += 1
        
        colour = [c for l, c in colours.items() if l in name][0]
        if debug: print(colour)
        style = '-'
        # style = '-' if "FULL" in name.upper() else '--'
        if debug: print(style)

        ax.plot(fpr, tpr, style, label='%s (AUC = %.4f)'%(name, auc), color=colour)

        for wp in eff_wps:
            bkgrejs[wp] = bkg_rej(tpr, fpr, wp)

        if debug: print(' - ', name, auc, [bkgrejs[wp] for wp in eff_wps], sep=',')
        
    #order = dict(sorted(aucs.items(), key=lambda item: item[1])).keys()
    #handels, labels = plt.gca().get_legend_handles_labels()
    
    #ax.legend([handels[idx] for idx in order],[labels[idx] for idx in order], loc='best', fontsize=16)

    ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="k", label="Random Chance")
    
    ax.legend(bbox_to_anchor=(1.04,1), loc="best")
    # ax.set_xscale('log')
    ax.set_xlim(1e-5 if auc > 0.999 else 1e-4, 1)
    ax.set_ylim(0.9 if auc > 0.999 else 0, 1)
    ax.set_ylabel('Signal efficiency', horizontalalignment='right', x=1.0)
    ax.set_xlabel('Background efficiency', horizontalalignment='right', y=1.0)
    ax.text(0.03, 0.95, comp_text, transform=ax.transAxes, fontsize=20, weight='bold')
    plt.title(title)
    plt.savefig(savename, bbox_inches='tight')

# %%
# Score Plot

def ScorePlot(comp_list, title='Scores', savename='testfig.png', comp_text=''):
    
    colours = {
        "Xbb vs QCD" : u'#1f77b4',
#        "b vs g" : u'#ff7f0e',
        "Xcc vs QCD" : u'#2ca02c',
#        "c vs g" : u'#d62728',
        "Xqq vs QCD" : u'#9467bd',
        "2prong vs QCD" : u'#ff7f0e',
#        "b vs c" : u'#ff7f0e'
    }
    debug = True
    
    f, ax = plt.subplots()

    prob_scores = {}
    idx = 0

    for name, cfg in comp_list.items():
        if debug: print(name)
        if debug: print(cfg)
        bkgrejs = {}
        if len(cfg['label']) == 6:
            sig = cfg['label'][0]
            bkgBB = cfg['label'][1]
            bkgCC = cfg['label'][2]
            bkgB = cfg['label'][3]
            bkgC = cfg['label'][4]
            bkgOthers = cfg['label'][5]
            sel = f"{cfg.get('selection')}"
        else:
            sigBB = cfg['label'][0]
            sigCC = cfg['label'][1]
            sigQQ = cfg['label'][2]
            bkgBB = cfg['label'][3]
            bkgCC = cfg['label'][4]
            bkgB = cfg['label'][5]
            bkgC = cfg['label'][6]
            bkgOthers = cfg['label'][7]
            sel = f"{cfg.get('selection')}"

        df = load_files(cfg['filepath'], treename=cfg.get('treename', 'Events'), 
                        filter_name=cfg.get('filter_name'), selection=sel)
        if debug: print(name, cfg['score'], sel, len(df), sep=",")

        y_pred = df.eval(cfg['score'])
        # print("y_pred:")
        # print(y_pred)
        print("Scores:")
        print(y_pred)
        # Debugging NaN values
        y_pred[np.isnan(y_pred)] = 0


        colour = [c for l, c in colours.items() if l in name][0]
        if debug: print(colour)
        style = '-'
        # style = '-' if "FULL" in name.upper() else '--'
        if debug: print(style)

        quark_score = ax.hist(y_pred, np.linspace(0, 1, 101), label=name, alpha=0.8, color=colour, histtype='step')

#        prob_scores[idx] = plt.hist(y_pred, np.linspace(0, 1, 101))

#        print(prob_scores[idx])
        
#        plt.plot(prob_scores[idx], color=colour, label=name)
        idx += 1

    # ax.show()
        
    # ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="k", label="Random Chance")
    
    ax.legend(bbox_to_anchor=(1.04,1), loc="best")
    ax.set_yscale('log')
    plt.title(title)
    plt.savefig(savename, bbox_inches='tight')
    # ax.set_xlim(1e-5 if auc > 0.999 else 1e-4, 1)
    # ax.set_ylim(0.9 if auc > 0.999 else 0, 1)
    # ax.set_ylabel('Signal efficiency', horizontalalignment='right', x=1.0)
    # ax.set_xlabel('Background efficiency', horizontalalignment='right', y=1.0)
    # ax.text(0.03, 0.95, comp_text, transform=ax.transAxes, fontsize=20, weight='bold')
    # plt.title(title)
    # plt.savefig(savename, bbox_inches='tight')

# %%
# Prob Plot

def ProbPlot(comp_list, title='Prob Scores', savename='testfig.png', comp_text=''):
    
    colours = {
        "Xbb" : u'#1f77b4',
        "Xcc" : u'#2ca02c',
        "Xqq" : u'#9467bd',
        "QCDbb" : u'#ff8f1e',
        "QCDcc" : u'#ef6f2e',
        "QCDb" : u'#de7f3e',
        "QCDc" : u'#cf3f4e',
        "QCDothers" : u'#bf705e',
    }
    debug = True
    
    f, ax = plt.subplots()

    prob_scores = {}
    idx = 0

    for name, cfg in comp_list.items():
        # if debug: print(name)
        # if debug: print(cfg)
        bkgrejs = {}
        if len(cfg['label']) == 6:
            sig = cfg['label'][0]
            bkgBB = cfg['label'][1]
            bkgCC = cfg['label'][2]
            bkgB = cfg['label'][3]
            bkgC = cfg['label'][4]
            bkgOthers = cfg['label'][5]
            sel = f"{cfg.get('selection')}"
        else:
            sigBB = cfg['label'][0]
            sigCC = cfg['label'][1]
            sigQQ = cfg['label'][2]
            bkgBB = cfg['label'][3]
            bkgCC = cfg['label'][4]
            bkgB = cfg['label'][5]
            bkgC = cfg['label'][6]
            bkgOthers = cfg['label'][7]
            sel = f"{cfg.get('selection')}"

        df = load_files(cfg['filepath'], treename=cfg.get('treename', 'Events'), 
                        filter_name=cfg.get('filter_name'), selection=sel)
        if debug: print(name, cfg['score'], sel, len(df), sep=",")

        #prob_score = df['score_probXqq']
        prob_score = df.eval(cfg['score'])
        # print("y_pred:")
        # print(y_pred)

        print("prob_score:")
        print(prob_score)

        colour = [c for l, c in colours.items() if l in name][0]
        if debug: print(colour)
        style = '-'
        # style = '-' if "FULL" in name.upper() else '--'
        if debug: print(style)

        prob_hist = ax.hist(prob_score, np.linspace(0, 1, 101), label=name, alpha=0.8, color=colour, histtype='step')

#        prob_scores[idx] = plt.hist(y_pred, np.linspace(0, 1, 101))

#        print(prob_scores[idx])
        
#        plt.plot(prob_scores[idx], color=colour, label=name)
        idx += 1

    # ax.show()
        
    # ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="k", label="Random Chance")
    
    ax.legend(bbox_to_anchor=(1.04,1), loc="best")
    ax.set_yscale('log')
    plt.title(title)
    plt.savefig(savename, bbox_inches='tight')
    # ax.set_xlim(1e-5 if auc > 0.999 else 1e-4, 1)
    # ax.set_ylim(0.9 if auc > 0.999 else 0, 1)
    # ax.set_ylabel('Signal efficiency', horizontalalignment='right', x=1.0)
    # ax.set_xlabel('Background efficiency', horizontalalignment='right', y=1.0)
    # ax.text(0.03, 0.95, comp_text, transform=ax.transAxes, fontsize=20, weight='bold')
    # plt.title(title)
    # plt.savefig(savename, bbox_inches='tight')

# %%
# Loss Plot

def LossPlot(train_log, title='Loss Curve', savename='testfig.png', trend=False):
    ifile = open(train_log, "r")
    loss_values = []
    validation_values = []
    for line in ifile:
        if "AvgLoss" in line:
            loss = line.split(", AvgAcc")
            loss = loss[0].split("AvgLoss: ")
            loss_values.append(float(loss[1]))
        # if "Current validation metric" in line:
        #     val_loss = line.split(" (best")
        #     val_loss = val_loss[0].split("metric: ")
        #     validation_values.append(float(val_loss[1]))
  #  print(loss_values)
    if trend == False:
        plt.plot(np.array(loss_values), label="Training Loss")
        # plt.plot(np.array(validation_values), label="Validation Loss")
        plt.ylabel("Loss")
        plt.xlabel("Epoch")
        plt.legend(bbox_to_anchor=(1.04,1), loc="best")
        plt.title(title)
        plt.savefig(savename, bbox_inches='tight')
    else:
        loss_trend = []
        for i in range(0,len(loss_values)-1):
            loss_trend.append(loss_values[i+1]-loss_values[i])
  #      print(loss_trend)
        plt.plot(np.array(loss_trend))
    #    plt.plot([0, 0], [len(loss_trend), 0], linestyle="--", lw=2, color="k", label="Random Chance")
        plt.axhline(y=0, linestyle="--", lw=2, color="k", label="Random Chance")
        plt.ylabel("Loss Trend")
        plt.xlabel("Epoch")
        plt.title(title)
        plt.savefig(savename, bbox_inches='tight')

# %%
# Accuracy Plot

def AccPlot(train_log, title='Accuracy Curve', savename='testfig.png'):
    ifile = open(train_log, "r")
    acc_values = []
    validation_values = []
    for line in ifile:
        if "AvgAcc" in line:
            acc = line.split("AvgAcc: ")
            acc_values.append(float(acc[1]))
        if "Current validation metric" in line:
            val_acc = line.split(" (best")
            val_acc = val_acc[0].split("metric: ")
            validation_values.append(float(val_acc[1]))
  #  print(loss_values)
    plt.plot(np.array(acc_values), label="Training Accuracy")
    plt.plot(np.array(validation_values), label="Validation Accuracy")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.legend(bbox_to_anchor=(1.04,1), loc="best")
    plt.title(title)
    plt.savefig(savename, bbox_inches='tight')

# %%
LossPlot("/home/akobert/ParticleNet/training/train_v8.log", "Loss Curve", "test_v8_loss_curve.png")

# %%
LossPlot("/home/akobert/ParticleNet/training/train_v8_lowPT.log", "Low pT Loss Curve", "test_v8_lowPT_loss_curve.png")

# %%
AccPlot("/home/akobert/ParticleNet/training/train_v8.log", "Accuracy Curve", "test_v8_acc_curve.png")

# %%
AccPlot("/home/akobert/ParticleNet/training/train_v8_lowPT.log", "Low pT Accuracy Curve", "test_v8_lowPT_acc_curve.png")

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

plot(algos, title='ROC Curve: Retrain, pT>110 GeV', savename='retrain_best_v8_pt110_ROC.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1488905
# y_pred:
# 2          0.252050
# 4          0.040422
# 5          0.002644
# 6          0.004834
# 7          0.032347
#              ...
# 1743411    0.085222
# 1743413    0.184782
# 1743414    0.113590
# 1743415    0.329455
# 1743416    0.619158
# Length: 1488905, dtype: float32
# y_true:
# [False False False ... False False False]
# #1f77b4
# -
#  - ,Xbb vs QCD,0.8398518204773762,[19.360511644941198]
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXcc==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1488947
# y_pred:
# 0          0.052539
# 2          0.753504
# 4          0.265853
# 5          0.015796
# 6          0.101697
#              ...
# 1743411    0.482178
# 1743413    0.739048
# 1743414    0.561189
# 1743415    0.895669
# 1743416    0.779002
# Length: 1488947, dtype: float32
# y_true:
# [ True False False ... False False False]
# #2ca02c
# -
#  - ,Xcc vs QCD,0.7126027580532129,[5.10497401580154]
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1620195
# y_pred:
# 1          0.903578
# 2          0.753919
# 3          0.593880
# 4          0.460014
# 5          0.017337
#              ...
# 1743412    0.720487
# 1743413    0.897565
# 1743414    0.783577
# 1743415    0.985549
# 1743416    0.387282
# Length: 1620195, dtype: float32
# y_true:
# [ True False  True ... False False False]
# #9467bd
# -
#  - ,Xqq vs QCD,0.7208699144935715,[5.090209126831287]
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probXcc==1 | probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1743417
# sigBB:
# [False False False ... False False False]
# sigCC:
# [ True False False ... False False False]
# sigQQ:
# [False  True False ... False False False]
# y_true:
# [ True  True False ... False False False]
# y_pred:
# 0          0.118028
# 1          0.918271
# 2          0.865908
# 3          0.817549
# 4          0.556767
#              ...
# 1743412    0.794390
# 1743413    0.922003
# 1743414    0.834097
# 1743415    0.987225
# 1743416    0.852567
# Length: 1743417, dtype: float32
# y_true:
# [ True  True False ... False False False]
# #ff7f0e
# -
#  - ,2prong vs QCD,0.6738053461400553,[4.009717274780596]

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

ScorePlot(algos, title='Retrain Score Plot pT>110 GeV', savename='retrain_best_v8_pt110_scores.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0          0.011515
# 1          0.112077
# 2          0.252050
# 3          0.257819
# 4          0.040422
#              ...
# 1743412    0.088601
# 1743413    0.184782
# 1743414    0.113590
# 1743415    0.329455
# 1743416    0.619158
# Length: 1743417, dtype: float32
# #1f77b4
# -
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0          0.052539
# 1          0.634816
# 2          0.753504
# 3          0.727611
# 4          0.265853
#              ...
# 1743412    0.543113
# 1743413    0.739048
# 1743414    0.561189
# 1743415    0.895669
# 1743416    0.779002
# Length: 1743417, dtype: float32
# #2ca02c
# -
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0          0.062548
# 1          0.903578
# 2          0.753919
# 3          0.593880
# 4          0.460014
#              ...
# 1743412    0.720487
# 1743413    0.897565
# 1743414    0.783577
# 1743415    0.985549
# 1743416    0.387282
# Length: 1743417, dtype: float32
# #9467bd
# -
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0          0.118028
# 1          0.918271
# 2          0.865908
# 3          0.817549
# 4          0.556767
#              ...
# 1743412    0.794390
# 1743413    0.922003
# 1743414    0.834097
# 1743415    0.987225
# 1743416    0.852567
# Length: 1743417, dtype: float32
# #ff7f0e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

bkgs = ["bb", "cc", "b", "c", "others"]

algos = {}

for sig in sigs:
    
    algos[f'prob{sig}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',

        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_prob{sig}',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }
for bkg in bkgs:
    
    algos[f'probQCD{bkg}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',

        'label' : [f'probQCD{bkg}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_probQCD{bkg}',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }


ProbPlot(algos, title='Retrain Prob Values pT>110 GeV', savename='retrain_best_v8_pt110_probs.png')
# Out:
# probXbb,score_probXbb,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.010274
# 1          0.010316
# 2          0.045187
# 3          0.063380
# 4          0.018671
#              ...
# 1743412    0.019988
# 1743413    0.017679
# 1743414    0.021260
# 1743415    0.006277
# 1743416    0.239690
# Length: 1743417, dtype: float32
# #1f77b4
# -
# probXcc,score_probXcc,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.048907
# 1          0.142073
# 2          0.409902
# 3          0.487366
# 4          0.160506
#              ...
# 1743412    0.244413
# 1743413    0.220896
# 1743414    0.212171
# 1743415    0.109675
# 1743416    0.519689
# Length: 1743417, dtype: float32
# #2ca02c
# -
# probXqq,score_probXqq,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.058846
# 1          0.765883
# 2          0.410818
# 3          0.266803
# 4          0.377590
#              ...
# 1743412    0.529989
# 1743413    0.683428
# 1743414    0.600666
# 1743415    0.871273
# 1743416    0.093188
# Length: 1743417, dtype: float32
# #9467bd
# -
# probQCDbb,score_probQCDbb,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.031325
# 1          0.001174
# 2          0.007303
# 3          0.014048
# 4          0.009605
#              ...
# 1743412    0.004483
# 1743413    0.001620
# 1743414    0.003463
# 1743415    0.000223
# 1743416    0.030634
# Length: 1743417, dtype: float32
# #ff8f1e
# -
# probQCDcc,score_probQCDcc,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.271010
# 1          0.013909
# 2          0.043720
# 3          0.067463
# 4          0.090354
#              ...
# 1743412    0.052858
# 1743413    0.017080
# 1743414    0.035270
# 1743415    0.002129
# 1743416    0.054140
# Length: 1743417, dtype: float32
# #ef6f2e
# -
# probQCDb,score_probQCDb,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.063512
# 1          0.004572
# 2          0.019885
# 3          0.030176
# 4          0.034483
#              ...
# 1743412    0.013495
# 1743413    0.005467
# 1743414    0.010334
# 1743415    0.000846
# 1743416    0.035782
# Length: 1743417, dtype: float32
# #de7f3e
# -
# probQCDc,score_probQCDc,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.163764
# 1          0.015693
# 2          0.031116
# 3          0.037543
# 4          0.101575
#              ...
# 1743412    0.039450
# 1743413    0.015752
# 1743414    0.030535
# 1743415    0.002180
# 1743416    0.015893
# Length: 1743417, dtype: float32
# #cf3f4e
# -
# probQCDothers,score_probQCDothers,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.352361
# 1          0.046381
# 2          0.032069
# 3          0.033221
# 4          0.207216
#              ...
# 1743412    0.095324
# 1743413    0.038078
# 1743414    0.086302
# 1743415    0.007398
# 1743416    0.010983
# Length: 1743417, dtype: float32
# #bf705e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4  & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

plot(algos, title='ROC Curve: Retrain, pT>200 GeV', savename='retrain_best_v8_pt200_ROC.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),358594
# y_pred:
# 8          0.043041
# 11         0.016269
# 13         0.110128
# 14         0.020700
# 15         0.416276
#              ...
# 1743401    0.791765
# 1743403    0.111205
# 1743404    0.008234
# 1743415    0.329455
# 1743416    0.619158
# Length: 358594, dtype: float32
# y_true:
# [False False False ... False False False]
# #1f77b4
# -
#  - ,Xbb vs QCD,0.8768353253106106,[27.51006330141211]
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXcc==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),359324
# y_pred:
# 8          0.180371
# 11         0.250387
# 13         0.530216
# 14         0.103237
# 15         0.887958
#              ...
# 1743401    0.599676
# 1743403    0.075236
# 1743404    0.030909
# 1743415    0.895669
# 1743416    0.779002
# Length: 359324, dtype: float32
# y_true:
# [False False False ... False False False]
# #2ca02c
# -
#  - ,Xcc vs QCD,0.7149839665221502,[4.930388492138525]
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),403837
# y_pred:
# 1          0.903578
# 8          0.268115
# 9          0.879940
# 11         0.738542
# 13         0.679083
#              ...
# 1743404    0.028451
# 1743409    0.192334
# 1743412    0.720487
# 1743415    0.985549
# 1743416    0.387282
# Length: 403837, dtype: float32
# y_true:
# [ True False  True ...  True False False]
# #9467bd
# -
#  - ,Xqq vs QCD,0.7095984032099689,[4.656496833660728]
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4  & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4  & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probXcc==1 | probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),443797
# sigBB:
# [False False False ... False False False]
# sigCC:
# [False False False ... False False False]
# sigQQ:
# [ True False  True ...  True False False]
# y_true:
# [ True False  True ...  True False False]
# y_pred:
# 1          0.918271
# 8          0.387021
# 9          0.890430
# 11         0.760494
# 13         0.771087
#              ...
# 1743404    0.064968
# 1743409    0.233493
# 1743412    0.794390
# 1743415    0.987225
# 1743416    0.852567
# Length: 443797, dtype: float32
# y_true:
# [ True False  True ...  True False False]
# #ff7f0e
# -
#  - ,2prong vs QCD,0.6751733811930247,[3.880520640153857]

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

ScorePlot(algos, title='Retrain Score Plot pT>200 GeV', savename='retrain_best_v8_pt200_scores.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,score_probXbb/(score_probXbb + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.112077
# 8          0.043041
# 9          0.022620
# 11         0.016269
# 13         0.110128
#              ...
# 1743404    0.008234
# 1743409    0.002669
# 1743412    0.088601
# 1743415    0.329455
# 1743416    0.619158
# Length: 443797, dtype: float32
# #1f77b4
# -
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,score_probXcc/(score_probXcc + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.634816
# 8          0.180371
# 9          0.436381
# 11         0.250387
# 13         0.530216
#              ...
# 1743404    0.030909
# 1743409    0.059981
# 1743412    0.543113
# 1743415    0.895669
# 1743416    0.779002
# Length: 443797, dtype: float32
# #2ca02c
# -
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,score_probXqq/(score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.903578
# 8          0.268115
# 9          0.879940
# 11         0.738542
# 13         0.679083
#              ...
# 1743404    0.028451
# 1743409    0.192334
# 1743412    0.720487
# 1743415    0.985549
# 1743416    0.387282
# Length: 443797, dtype: float32
# #9467bd
# -
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.918271
# 8          0.387021
# 9          0.890430
# 11         0.760494
# 13         0.771087
#              ...
# 1743404    0.064968
# 1743409    0.233493
# 1743412    0.794390
# 1743415    0.987225
# 1743416    0.852567
# Length: 443797, dtype: float32
# #ff7f0e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

bkgs = ["bb", "cc", "b", "c", "others"]

algos = {}

for sig in sigs:
    
    algos[f'prob{sig}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',

        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_prob{sig}',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }
for bkg in bkgs:
    
    algos[f'probQCD{bkg}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',

        'label' : [f'probQCD{bkg}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'score_probQCD{bkg}',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }


ProbPlot(algos, title='Retrain Prob Values pT>200 GeV', savename='retrain_best_v8_pt200_probs.png')
# Out:
# probXbb,score_probXbb,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.010316
# 8          0.027570
# 9          0.002536
# 11         0.003961
# 13         0.028330
#              ...
# 1743404    0.007763
# 1743409    0.002051
# 1743412    0.019988
# 1743415    0.006277
# 1743416    0.239690
# Length: 443797, dtype: float32
# #1f77b4
# -
# probXcc,score_probXcc,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.142073
# 8          0.134895
# 9          0.084835
# 11         0.080000
# 13         0.258361
#              ...
# 1743404    0.029823
# 1743409    0.048910
# 1743412    0.244413
# 1743415    0.109675
# 1743416    0.519689
# Length: 443797, dtype: float32
# #2ca02c
# -
# probXqq,score_probXqq,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.765883
# 8          0.224556
# 9          0.803060
# 11         0.676533
# 13         0.484396
#              ...
# 1743404    0.027381
# 1743409    0.182532
# 1743412    0.529989
# 1743415    0.871273
# 1743416    0.093188
# Length: 443797, dtype: float32
# #9467bd
# -
# probQCDbb,score_probQCDbb,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.001174
# 8          0.025449
# 9          0.000670
# 11         0.002041
# 13         0.010814
#              ...
# 1743404    0.045636
# 1743409    0.005301
# 1743412    0.004483
# 1743415    0.000223
# 1743416    0.030634
# Length: 443797, dtype: float32
# #ff8f1e
# -
# probQCDcc,score_probQCDcc,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.013909
# 8          0.168475
# 9          0.017427
# 11         0.035878
# 13         0.067155
#              ...
# 1743404    0.350647
# 1743409    0.150805
# 1743412    0.052858
# 1743415    0.002129
# 1743416    0.054140
# Length: 443797, dtype: float32
# #ef6f2e
# -
# probQCDb,score_probQCDb,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.004572
# 8          0.045326
# 9          0.004333
# 11         0.009907
# 13         0.026019
#              ...
# 1743404    0.077271
# 1743409    0.025630
# 1743412    0.013495
# 1743415    0.000846
# 1743416    0.035782
# Length: 443797, dtype: float32
# #de7f3e
# -
# probQCDc,score_probQCDc,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.015693
# 8          0.099193
# 9          0.020512
# 11         0.044391
# 13         0.046087
#              ...
# 1743404    0.151385
# 1743409    0.137168
# 1743412    0.039450
# 1743415    0.002180
# 1743416    0.015893
# Length: 443797, dtype: float32
# #cf3f4e
# -
# probQCDothers,score_probQCDothers,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.046381
# 8          0.274537
# 9          0.066628
# 11         0.147289
# 13         0.078838
#              ...
# 1743404    0.310093
# 1743409    0.447603
# 1743412    0.095324
# 1743415    0.007398
# 1743416    0.010983
# Length: 443797, dtype: float32
# #bf705e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        # 'filepath' : '/home/akobert/ParticleNet/training/output/standard6_onnx.root',
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        # 'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'score' : f'pfMassDecorrelatedParticleNetJetTags_prob{sig}/(pfMassDecorrelatedParticleNetJetTags_prob{sig} + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    # 'filepath' : '/home/akobert/ParticleNet/training/output/standard6_onnx.root',
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    # 'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'score' : '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
    'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

plot(algos, title='ROC Curve: Standard ParticleNet, pT>110 GeV', savename='standard_best_v8_pt110_ROC.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1488905
# y_pred:
# 2               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7          0.000332
#              ...
# 1743411    0.006116
# 1743413    0.013331
# 1743414         NaN
# 1743415    0.000985
# 1743416    0.244176
# Length: 1488905, dtype: float32
# y_true:
# [False False False ... False False False]
# #1f77b4
# -
#  - ,Xbb vs QCD,0.6526536598322866,[7.0101469988752845]
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXcc==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1488947
# y_pred:
# 0               NaN
# 2               NaN
# 4               NaN
# 5               NaN
# 6               NaN
#              ...
# 1743411    0.109476
# 1743413    0.428811
# 1743414         NaN
# 1743415    0.020536
# 1743416    0.804481
# Length: 1488947, dtype: float32
# y_true:
# [ True False False ... False False False]
# #2ca02c
# -
#  - ,Xcc vs QCD,0.6593820526957392,[8.391084015779047]
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1620195
# y_pred:
# 1          0.973455
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
#              ...
# 1743412    0.744099
# 1743413    0.459657
# 1743414         NaN
# 1743415    0.043303
# 1743416    0.530882
# Length: 1620195, dtype: float32
# y_true:
# [ True False  True ... False False False]
# #9467bd
# -
#  - ,Xqq vs QCD,0.6406275021756479,[4.889203650165107]
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probXcc==1 | probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),1743417
# sigBB:
# [False False False ... False False False]
# sigCC:
# [ True False False ... False False False]
# sigQQ:
# [False  True False ... False False False]
# y_true:
# [ True  True False ... False False False]
# y_pred:
# 0               NaN
# 1          0.974048
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1743412    0.776793
# 1743413    0.617579
# 1743414         NaN
# 1743415    0.062982
# 1743416    0.847777
# Length: 1743417, dtype: float32
# y_true:
# [ True  True False ... False False False]
# #ff7f0e
# -
#  - ,2prong vs QCD,0.6328857597652786,[4.309890328892539]

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'pfMassDecorrelatedParticleNetJetTags_prob{sig}/(pfMassDecorrelatedParticleNetJetTags_prob{sig} + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
        # 'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    # 'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'score' : '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
    'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

ScorePlot(algos, title='Standard ParticleNet Score Plot pT>110', savename='standard_best_v8_pt110_scores.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0               NaN
# 1          0.000983
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1743412    0.012371
# 1743413    0.013331
# 1743414         NaN
# 1743415    0.000985
# 1743416    0.244176
# Length: 1743417, dtype: float32
# #1f77b4
# -
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0               NaN
# 1          0.462310
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1743412    0.358916
# 1743413    0.428811
# 1743414         NaN
# 1743415    0.020536
# 1743416    0.804481
# Length: 1743417, dtype: float32
# #2ca02c
# -
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0               NaN
# 1          0.973455
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1743412    0.744099
# 1743413    0.459657
# 1743414         NaN
# 1743415    0.043303
# 1743416    0.530882
# Length: 1743417, dtype: float32
# #9467bd
# -
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# Scores:
# 0               NaN
# 1          0.974048
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1743412    0.776793
# 1743413    0.617579
# 1743414         NaN
# 1743415    0.062982
# 1743416    0.847777
# Length: 1743417, dtype: float32
# #ff7f0e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

bkgs = ["bb", "cc", "b", "c", "others"]

algos = {}

for sig in sigs:
    
    algos[f'prob{sig}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',

        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'pfMassDecorrelatedParticleNetJetTags_prob{sig}',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }
for bkg in bkgs:
    
    algos[f'probQCD{bkg}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test7_PN_test.root',

        'label' : [f'probQCD{bkg}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'pfMassDecorrelatedParticleNetJetTags_probQCD{bkg}',
        'selection' : 'fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }


ProbPlot(algos, title='Standard ParticleNet Prob Values pT>110 GeV', savename='standard_best_v8_pt110_probs.png')
# Out:
# probXbb,pfMassDecorrelatedParticleNetJetTags_probXbb,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.000026
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.002796
# 1743413    0.005167
# 1743414    0.000000
# 1743415    0.000924
# 1743416    0.049177
# Length: 1743417, dtype: float32
# #1f77b4
# -
# probXcc,pfMassDecorrelatedParticleNetJetTags_probXcc,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.022314
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.124964
# 1743413    0.287096
# 1743414    0.000000
# 1743415    0.019646
# 1743416    0.626335
# Length: 1743417, dtype: float32
# #2ca02c
# -
# probXqq,pfMassDecorrelatedParticleNetJetTags_probXqq,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.951708
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.649033
# 1743413    0.325316
# 1743414    0.000000
# 1743415    0.042413
# 1743416    0.172265
# Length: 1743417, dtype: float32
# #9467bd
# -
# probQCDbb,pfMassDecorrelatedParticleNetJetTags_probQCDbb,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000e+00
# 1          5.425145e-07
# 2          0.000000e+00
# 3          0.000000e+00
# 4          0.000000e+00
#                ...
# 1743412    2.609686e-04
# 1743413    3.844740e-04
# 1743414    0.000000e+00
# 1743415    3.253050e-04
# 1743416    1.668654e-02
# Length: 1743417, dtype: float32
# #ff8f1e
# -
# probQCDcc,pfMassDecorrelatedParticleNetJetTags_probQCDcc,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.000179
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.013713
# 1743413    0.016565
# 1743414    0.000000
# 1743415    0.007197
# 1743416    0.048986
# Length: 1743417, dtype: float32
# #ef6f2e
# -
# probQCDb,pfMassDecorrelatedParticleNetJetTags_probQCDb,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.000078
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.000997
# 1743413    0.002885
# 1743414    0.000000
# 1743415    0.012663
# 1743416    0.010329
# Length: 1743417, dtype: float32
# #de7f3e
# -
# probQCDc,pfMassDecorrelatedParticleNetJetTags_probQCDc,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.001477
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.008888
# 1743413    0.037316
# 1743414    0.000000
# 1743415    0.054879
# 1743416    0.010860
# Length: 1743417, dtype: float32
# #cf3f4e
# -
# probQCDothers,pfMassDecorrelatedParticleNetJetTags_probQCDothers,fj_pt>110 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,1743417
# prob_score:
# 0          0.000000
# 1          0.024219
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 1743412    0.199347
# 1743413    0.325270
# 1743414    0.000000
# 1743415    0.861953
# 1743416    0.065362
# Length: 1743417, dtype: float32
# #bf705e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        # 'filepath' : '/home/akobert/ParticleNet/training/output/standard6_onnx.root',
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        # 'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'score' : f'pfMassDecorrelatedParticleNetJetTags_prob{sig}/(pfMassDecorrelatedParticleNetJetTags_prob{sig} + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    # 'filepath' : '/home/akobert/ParticleNet/training/output/standard6_onnx.root',
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    # 'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'score' : '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
    'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

plot(algos, title='ROC Curve: Standard ParticleNet, pT>200 GeV', savename='standard_best_v8_pt200_ROC.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),358594
# y_pred:
# 8          0.041945
# 11         0.000053
# 13         0.000455
# 14         0.000084
# 15         0.042144
#              ...
# 1743401    0.991793
# 1743403    0.059482
# 1743404    0.001280
# 1743415    0.000985
# 1743416    0.244176
# Length: 358594, dtype: float32
# y_true:
# [False False False ... False False False]
# #1f77b4
# -
#  - ,Xbb vs QCD,0.9157192878110769,[193.59166190748144]
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXcc==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),359324
# y_pred:
# 8          0.313949
# 11         0.024797
# 13         0.086637
# 14         0.003727
# 15         0.874444
#              ...
# 1743401    0.018219
# 1743403    0.361966
# 1743404    0.020908
# 1743415    0.020536
# 1743416    0.804481
# Length: 359324, dtype: float32
# y_true:
# [False False False ... False False False]
# #2ca02c
# -
#  - ,Xcc vs QCD,0.9054073656809345,[46.83324122685825]
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),403837
# y_pred:
# 1          0.973455
# 8          0.621568
# 9          0.731960
# 11         0.511268
# 13         0.444820
#              ...
# 1743404    0.009434
# 1743409    0.375149
# 1743412    0.744099
# 1743415    0.043303
# 1743416    0.530882
# Length: 403837, dtype: float32
# y_true:
# [ True False  True ...  True False False]
# #9467bd
# -
#  - ,Xqq vs QCD,0.8306854687613354,[11.888994107744107]
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250 & (probXbb==1 | probXcc==1 | probXqq==1 | probQCDbb==1 | probQCDcc==1 | probQCDb==1 | probQCDc==1 | probQCDothers==1),443797
# sigBB:
# [False False False ... False False False]
# sigCC:
# [False False False ... False False False]
# sigQQ:
# [ True False  True ...  True False False]
# y_true:
# [ True False  True ...  True False False]
# y_pred:
# 1          0.974048
# 8          0.681922
# 9          0.743792
# 11         0.517279
# 13         0.472720
#              ...
# 1743404    0.031158
# 1743409    0.415906
# 1743412    0.776793
# 1743415    0.062982
# 1743416    0.847777
# Length: 443797, dtype: float32
# y_true:
# [ True False  True ...  True False False]
# #ff7f0e
# -
#  - ,2prong vs QCD,0.8210384249743581,[11.578337944461524]

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

algos = {}

for sig in sigs:
    
    algos[f'{sig} vs QCD'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
#         'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220531-072338_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/a/adlintul/scouting/particlenet/kubeflow/outputs/train_pixelOnly_vs_Full-20220529-202709_particlenet_pf_ranger_lr0.005_batch512/predict_output/pred.root',
        #'filepath' : '/eos/user/p/phmaster/data/adelina_tmp/predict_output_pixel.root',
        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'pfMassDecorrelatedParticleNetJetTags_prob{sig}/(pfMassDecorrelatedParticleNetJetTags_prob{sig} + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
        # 'score' : f'score_prob{sig}/(score_prob{sig} + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }

algos['2prong vs QCD'] = {
    'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',
    'label' : ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
    # 'score' : '(score_probXbb + score_probXcc + score_probXqq)/(score_probXbb + score_probXcc + score_probXqq + score_probQCDbb + score_probQCDcc + score_probQCDb + score_probQCDc + score_probQCDothers)',
    'score' : '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)',
    'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
}

ScorePlot(algos, title='Standard ParticleNet Score Plot pT>200 GeV', savename='standard_best_v8_pt200_scores.png')
# Out:
# Xbb vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xbb vs QCD,pfMassDecorrelatedParticleNetJetTags_probXbb/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.000983
# 8          0.041945
# 9          0.002435
# 11         0.000053
# 13         0.000455
#              ...
# 1743404    0.001280
# 1743409    0.001649
# 1743412    0.012371
# 1743415    0.000985
# 1743416    0.244176
# Length: 443797, dtype: float32
# #1f77b4
# -
# Xcc vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXcc', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xcc vs QCD,pfMassDecorrelatedParticleNetJetTags_probXcc/(pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.462310
# 8          0.313949
# 9          0.145191
# 11         0.024797
# 13         0.086637
#              ...
# 1743404    0.020908
# 1743409    0.099117
# 1743412    0.358916
# 1743415    0.020536
# 1743416    0.804481
# Length: 443797, dtype: float32
# #2ca02c
# -
# Xqq vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': 'pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# Xqq vs QCD,pfMassDecorrelatedParticleNetJetTags_probXqq/(pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.973455
# 8          0.621568
# 9          0.731960
# 11         0.511268
# 13         0.444820
#              ...
# 1743404    0.009434
# 1743409    0.375149
# 1743412    0.744099
# 1743415    0.043303
# 1743416    0.530882
# Length: 443797, dtype: float32
# #9467bd
# -
# 2prong vs QCD
# {'filepath': '/home/akobert/ParticleNet/training/output/test8.root', 'label': ['probXbb', 'probXcc', 'probXqq', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'], 'score': '(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers)', 'selection': 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'}
# 2prong vs QCD,(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq)/(pfMassDecorrelatedParticleNetJetTags_probXbb + pfMassDecorrelatedParticleNetJetTags_probXcc + pfMassDecorrelatedParticleNetJetTags_probXqq + pfMassDecorrelatedParticleNetJetTags_probQCDbb + pfMassDecorrelatedParticleNetJetTags_probQCDcc + pfMassDecorrelatedParticleNetJetTags_probQCDb + pfMassDecorrelatedParticleNetJetTags_probQCDc + pfMassDecorrelatedParticleNetJetTags_probQCDothers),fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# Scores:
# 1          0.974048
# 8          0.681922
# 9          0.743792
# 11         0.517279
# 13         0.472720
#              ...
# 1743404    0.031158
# 1743409    0.415906
# 1743412    0.776793
# 1743415    0.062982
# 1743416    0.847777
# Length: 443797, dtype: float32
# #ff7f0e
# -

# %%
sigs = ["Xbb", "Xcc", "Xqq"]

bkgs = ["bb", "cc", "b", "c", "others"]

algos = {}

for sig in sigs:
    
    algos[f'prob{sig}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test8.root',

        'label' : [f'prob{sig}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'pfMassDecorrelatedParticleNetJetTags_prob{sig}',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }
for bkg in bkgs:
    
    algos[f'probQCD{bkg}'] = {
        'filepath' : '/home/akobert/ParticleNet/training/output/test7_PN_test.root',

        'label' : [f'probQCD{bkg}', 'probQCDbb', 'probQCDcc', 'probQCDb', 'probQCDc', 'probQCDothers'],
        'score' : f'pfMassDecorrelatedParticleNetJetTags_probQCD{bkg}',
        'selection' : 'fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250'
    }


ProbPlot(algos, title='Standard ParticleNet Prob Values pT>200 GeV', savename='standard_best_v7_pt200_probs.png')
# Out:
# probXbb,pfMassDecorrelatedParticleNetJetTags_probXbb,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.000026
# 8          0.013926
# 9          0.000625
# 11         0.000026
# 13         0.000240
#              ...
# 1743404    0.001242
# 1743409    0.000964
# 1743412    0.002796
# 1743415    0.000924
# 1743416    0.049177
# Length: 443797, dtype: float32
# #1f77b4
# -
# probXcc,pfMassDecorrelatedParticleNetJetTags_probXcc,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.022314
# 8          0.145558
# 9          0.043517
# 11         0.012274
# 13         0.050015
#              ...
# 1743404    0.020689
# 1743409    0.064263
# 1743412    0.124964
# 1743415    0.019646
# 1743416    0.626335
# Length: 443797, dtype: float32
# #2ca02c
# -
# probXqq,pfMassDecorrelatedParticleNetJetTags_probXqq,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.951708
# 8          0.522438
# 9          0.699649
# 11         0.504979
# 13         0.422465
#              ...
# 1743404    0.009227
# 1743409    0.350679
# 1743412    0.649033
# 1743415    0.042413
# 1743416    0.172265
# Length: 443797, dtype: float32
# #9467bd
# -
# probQCDbb,pfMassDecorrelatedParticleNetJetTags_probQCDbb,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          5.425145e-07
# 8          1.359615e-03
# 9          1.382045e-04
# 11         1.010243e-05
# 13         1.179080e-04
#                ...
# 1743404    8.658248e-04
# 1743409    1.221417e-04
# 1743412    2.609686e-04
# 1743415    3.253050e-04
# 1743416    1.668654e-02
# Length: 443797, dtype: float32
# #ff8f1e
# -
# probQCDcc,pfMassDecorrelatedParticleNetJetTags_probQCDcc,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.000179
# 8          0.018492
# 9          0.007330
# 11         0.002096
# 13         0.007840
#              ...
# 1743404    0.057649
# 1743409    0.013406
# 1743412    0.013713
# 1743415    0.007197
# 1743416    0.048986
# Length: 443797, dtype: float32
# #ef6f2e
# -
# probQCDb,pfMassDecorrelatedParticleNetJetTags_probQCDb,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.000078
# 8          0.004357
# 9          0.001246
# 11         0.001276
# 13         0.001694
#              ...
# 1743404    0.009773
# 1743409    0.002148
# 1743412    0.000997
# 1743415    0.012663
# 1743416    0.010329
# Length: 443797, dtype: float32
# #de7f3e
# -
# probQCDc,pfMassDecorrelatedParticleNetJetTags_probQCDc,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.001477
# 8          0.021111
# 9          0.013680
# 11         0.023687
# 13         0.021220
#              ...
# 1743404    0.063995
# 1743409    0.035172
# 1743412    0.008888
# 1743415    0.054879
# 1743416    0.010860
# Length: 443797, dtype: float32
# #cf3f4e
# -
# probQCDothers,pfMassDecorrelatedParticleNetJetTags_probQCDothers,fj_pt>200 & fj_eta>-2.4 & fj_eta<2.4 & fj_corrsdmass > 1 & fj_corrsdmass < 250,443797
# prob_score:
# 1          0.024219
# 8          0.272758
# 9          0.233814
# 11         0.455652
# 13         0.496407
#              ...
# 1743404    0.836559
# 1743409    0.533245
# 1743412    0.199347
# 1743415    0.861953
# 1743416    0.065362
# Length: 443797, dtype: float32
# #bf705e
# -
