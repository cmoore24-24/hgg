# %%
import numpy as np
import matplotlib.pyplot as plt 
import pickle

# %%
with open("../../outputs/n4/hgg_n4.pkl", "rb") as f:
    hgg_n4 = pickle.load(f)
with open("../../outputs/n4/hbb_n4.pkl", "rb") as f:
    hbb_n4 = pickle.load(f)
with open("../../outputs/n4/q347_n4.pkl", "rb") as f:
    q347_n4 = pickle.load(f)
with open("../../outputs/n4/q476_n4.pkl", "rb") as f:
    q476_n4 = pickle.load(f)
with open("../../outputs/n4/q68_n4.pkl", "rb") as f:
    q68_n4 = pickle.load(f)
with open("../../outputs/n4/q810_n4.pkl", "rb") as f:
    q810_n4 = pickle.load(f)
with open("../../outputs/n4/q1014_n4.pkl", "rb") as f:
    q1014_n4 = pickle.load(f)
with open("../../outputs/n4/q1418_n4.pkl", "rb") as f:
    q1418_n4 = pickle.load(f)
with open("../../outputs/n4/q1824_n4.pkl", "rb") as f:
    q1824_n4 = pickle.load(f)
with open("../../outputs/n4/q2432_n4.pkl", "rb") as f:
    q2432_n4 = pickle.load(f)
with open("../../outputs/n4/q32inf_n4.pkl", "rb") as f:
    q32inf_n4 = pickle.load(f)
with open("../../outputs/n4/n2_n3_d2_d3.pkl", "rb") as f:
    ecfs = pickle.load(f)

# %%
scalesHJ = ((44.99*(0.471*1000)*0.0817)/(hgg_n4[0]['Hgg']['Hgg']['entries']))
scalesHbb = ((44.99*(0.274*1000)*0.581)/(hbb_n4[0]['Hbb']['Hbb']['entries']))

scalesHJ = ((44.99*(0.471*1000)*0.0817)/(ecfs[0]['Hgg']['Hgg']['entries']))
scalesHbb = ((44.99*(0.274*1000)*0.581)/(ecfs[0]['Hbb']['Hbb']['entries']))

# %%
hbb_n4[0]['Hbb']['Hbb']['N4'].view(flow=True)[:] *= scalesHbb
hgg_n4[0]['Hgg']['Hgg']['N4'].view(flow=True)[:] *= scalesHJ

ecfs[0]['Hbb']['Hbb']['N2'].view(flow=True)[:] *= scalesHbb
ecfs[0]['Hgg']['Hgg']['N2'].view(flow=True)[:] *= scalesHJ

ecfs[0]['Hbb']['Hbb']['N3'].view(flow=True)[:] *= scalesHbb
ecfs[0]['Hgg']['Hgg']['N3'].view(flow=True)[:] *= scalesHJ

ecfs[0]['Hbb']['Hbb']['D2'].view(flow=True)[:] *= scalesHbb
ecfs[0]['Hgg']['Hgg']['D2'].view(flow=True)[:] *= scalesHJ

ecfs[0]['Hbb']['Hbb']['D3'].view(flow=True)[:] *= scalesHbb
ecfs[0]['Hgg']['Hgg']['D3'].view(flow=True)[:] *= scalesHJ

# %%
n4_hgg_total = hgg_n4[0]['Hgg']['Hgg']['N4'][0:40:sum]
n4_hbb_total = hbb_n4[0]['Hbb']['Hbb']['N4'][0:40:sum]

n2_hgg_total = ecfs[0]['Hgg']['Hgg']['N2'][0:40:sum]
n2_hbb_total = ecfs[0]['Hbb']['Hbb']['N2'][0:40:sum]

n3_hgg_total = ecfs[0]['Hgg']['Hgg']['N3'][0:40:sum]
n3_hbb_total = ecfs[0]['Hbb']['Hbb']['N3'][0:40:sum]

d2_hgg_total = ecfs[0]['Hgg']['Hgg']['D2'][0:40:sum]
d2_hbb_total = ecfs[0]['Hbb']['Hbb']['D2'][0:40:sum]

d3_hgg_total = ecfs[0]['Hgg']['Hgg']['D3'][0:40:sum]
d3_hbb_total = ecfs[0]['Hbb']['Hbb']['D3'][0:40:sum]

# %%
hgg_n4_true_positive = []
for i in range(1, 41):
    hgg_n4_true_positive.append(hgg_n4[0]['Hgg']['Hgg']['N4'][0:i:sum].value/n4_hgg_total.value)
#hgg_n4_true_positive.insert(0,0)

hbb_n4_true_positive = []
for i in range(1, 41):
    hbb_n4_true_positive.append(hbb_n4[0]['Hbb']['Hbb']['N4'][0:i:sum].value/n4_hbb_total.value)
#hbb_cr_true_positive.insert(0,0)

hgg_n2_true_positive = []
for i in range(1, 41):
    hgg_n2_true_positive.append(ecfs[0]['Hgg']['Hgg']['N2'][0:i:sum].value/n2_hgg_total.value)
#hgg_n4_true_positive.insert(0,0)

hbb_n2_true_positive = []
for i in range(1, 41):
    hbb_n2_true_positive.append(ecfs[0]['Hbb']['Hbb']['N2'][0:i:sum].value/n2_hbb_total.value)
#hbb_cr_true_positive.insert(0,0)

hgg_n3_true_positive = []
for i in range(1, 41):
    hgg_n3_true_positive.append(ecfs[0]['Hgg']['Hgg']['N3'][0:i:sum].value/n3_hgg_total.value)
#hgg_n4_true_positive.insert(0,0)

hbb_n3_true_positive = []
for i in range(1, 41):
    hbb_n3_true_positive.append(ecfs[0]['Hbb']['Hbb']['N3'][0:i:sum].value/n3_hbb_total.value)
#hbb_cr_true_positive.insert(0,0)

hgg_d2_true_positive = []
for i in range(1, 41):
    hgg_d2_true_positive.append(ecfs[0]['Hgg']['Hgg']['D2'][0:i:sum].value/d2_hgg_total.value)
#hgg_n4_true_positive.insert(0,0)

hbb_d2_true_positive = []
for i in range(1, 41):
    hbb_d2_true_positive.append(ecfs[0]['Hbb']['Hbb']['D2'][0:i:sum].value/d2_hbb_total.value)
#hbb_cr_true_positive.insert(0,0)

hgg_d3_true_positive = []
for i in range(1, 41):
    hgg_d3_true_positive.append(ecfs[0]['Hgg']['Hgg']['D3'][0:i:sum].value/d3_hgg_total.value)
#hgg_n4_true_positive.insert(0,0)

hbb_d3_true_positive = []
for i in range(1, 41):
    hbb_d3_true_positive.append(ecfs[0]['Hbb']['Hbb']['D3'][0:i:sum].value/d3_hbb_total.value)
#hbb_cr_true_positive.insert(0,0)

# %%
#2017 integrated luminosity and QCD cross sections
IL = 44.99
xs_300to470 = 6833
xs_470to600 = 549.5
xs_600to800 = 156.5
xs_800to1000 = 26.22
xs_1000to1400 = 7.475
xs_1400to1800 = 0.6482
xs_1800to2400 = 0.08742
xs_2400to3200 = 0.005237
xs_3200toInf = 0.0001353

# %%
#QCD scale factors
scales300to470 = (((xs_300to470*1000)*IL)/(q347_n4[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['entries']))
scales470to600 = (((xs_470to600*1000)*IL)/(q476_n4[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['entries']))
scales600to800 = (((xs_600to800*1000)*IL)/(q68_n4[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['entries']))
scales800to1000 = (((xs_800to1000*1000)*IL)/(q810_n4[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['entries']))
scales1000to1400 = (((xs_1000to1400*1000)*IL)/(q1014_n4[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['entries']))
scales1400to1800 = (((xs_1400to1800*1000)*IL)/(q1418_n4[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['entries']))
scales1800to2400 = (((xs_1800to2400*1000)*IL)/(q1824_n4[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['entries']))
scales2400to3200 = (((xs_2400to3200*1000)*IL)/(q2432_n4[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['entries']))
scales3200toInf = (((xs_3200toInf*1000)*IL)/(q32inf_n4[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['entries']))

scales300to470 = (((xs_300to470*1000)*IL)/(ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['entries']))
scales470to600 = (((xs_470to600*1000)*IL)/(ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['entries']))
scales600to800 = (((xs_600to800*1000)*IL)/(ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['entries']))
scales800to1000 = (((xs_800to1000*1000)*IL)/(ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['entries']))
scales1000to1400 = (((xs_1000to1400*1000)*IL)/(ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['entries']))
scales1400to1800 = (((xs_1400to1800*1000)*IL)/(ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['entries']))
scales1800to2400 = (((xs_1800to2400*1000)*IL)/(ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['entries']))
scales2400to3200 = (((xs_2400to3200*1000)*IL)/(ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['entries']))
scales3200toInf = (((xs_3200toInf*1000)*IL)/(ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['entries']))

# %%
q347_n4[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N4'].view(flow=True)[:] *= scales300to470
q476_n4[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N4'].view(flow=True)[:] *= scales470to600
q68_n4[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N4'].view(flow=True)[:] *= scales600to800
q810_n4[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N4'].view(flow=True)[:] *= scales800to1000
q1014_n4[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N4'].view(flow=True)[:] *= scales1000to1400
q1418_n4[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N4'].view(flow=True)[:] *= scales1400to1800
q1824_n4[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N4'].view(flow=True)[:] *= scales1800to2400
q2432_n4[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N4'].view(flow=True)[:] *= scales2400to3200
q32inf_n4[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N4'].view(flow=True)[:] *= scales3200toInf

ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N2'].view(flow=True)[:] *= scales300to470
ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N2'].view(flow=True)[:] *= scales470to600
ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N2'].view(flow=True)[:] *= scales600to800
ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N2'].view(flow=True)[:] *= scales800to1000
ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N2'].view(flow=True)[:] *= scales1000to1400
ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N2'].view(flow=True)[:] *= scales1400to1800
ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N2'].view(flow=True)[:] *= scales1800to2400
ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N2'].view(flow=True)[:] *= scales2400to3200
ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N2'].view(flow=True)[:] *= scales3200toInf

ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N3'].view(flow=True)[:] *= scales300to470
ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N3'].view(flow=True)[:] *= scales470to600
ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N3'].view(flow=True)[:] *= scales600to800
ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N3'].view(flow=True)[:] *= scales800to1000
ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N3'].view(flow=True)[:] *= scales1000to1400
ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N3'].view(flow=True)[:] *= scales1400to1800
ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N3'].view(flow=True)[:] *= scales1800to2400
ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N3'].view(flow=True)[:] *= scales2400to3200
ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N3'].view(flow=True)[:] *= scales3200toInf

ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D2'].view(flow=True)[:] *= scales300to470
ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D2'].view(flow=True)[:] *= scales470to600
ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D2'].view(flow=True)[:] *= scales600to800
ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D2'].view(flow=True)[:] *= scales800to1000
ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D2'].view(flow=True)[:] *= scales1000to1400
ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D2'].view(flow=True)[:] *= scales1400to1800
ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D2'].view(flow=True)[:] *= scales1800to2400
ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D2'].view(flow=True)[:] *= scales2400to3200
ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D2'].view(flow=True)[:] *= scales3200toInf

ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D3'].view(flow=True)[:] *= scales300to470
ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D3'].view(flow=True)[:] *= scales470to600
ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D3'].view(flow=True)[:] *= scales600to800
ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D3'].view(flow=True)[:] *= scales800to1000
ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D3'].view(flow=True)[:] *= scales1000to1400
ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D3'].view(flow=True)[:] *= scales1400to1800
ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D3'].view(flow=True)[:] *= scales1800to2400
ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D3'].view(flow=True)[:] *= scales2400to3200
ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D3'].view(flow=True)[:] *= scales3200toInf

# %%
qcd_n4 = (q347_n4[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N4']+
        q476_n4[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N4']+
        q68_n4[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N4']+
        q810_n4[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N4']+
        q1014_n4[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N4']+
        q1418_n4[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N4']+
        q1824_n4[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N4']+
        q2432_n4[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N4']+
        q32inf_n4[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N4'])

qcd_n2 = (ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N2']+
        ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N2']+
        ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N2']+
        ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N2']+
        ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N2']+
        ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N2']+
        ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N2']+
        ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N2']+
        ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N2'])

qcd_n3 = (ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['N3']+
        ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['N3']+
        ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['N3']+
        ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['N3']+
        ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['N3']+
        ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['N3']+
        ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['N3']+
        ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['N3']+
        ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['N3'])

qcd_d2 = (ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D2']+
        ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D2']+
        ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D2']+
        ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D2']+
        ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D2']+
        ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D2']+
        ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D2']+
        ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D2']+
        ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D2'])

qcd_d3 = (ecfs[0]['QCD_Pt_300to470_TuneCP5_13TeV_pythia8']['QCD_Pt_300to470']['D3']+
        ecfs[0]['QCD_Pt_470to600_TuneCP5_13TeV_pythia8']['QCD_Pt_470to600']['D3']+
        ecfs[0]['QCD_Pt_600to800_TuneCP5_13TeV_pythia8']['QCD_Pt_600to800']['D3']+
        ecfs[0]['QCD_Pt_800to1000_TuneCP5_13TeV_pythia8']['QCD_Pt_800to1000']['D3']+
        ecfs[0]['QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8']['QCD_Pt_1000to1400']['D3']+
        ecfs[0]['QCD_Pt_1400to1800_TuneCP5_13TeV_pythia8']['QCD_Pt_1400to1800']['D3']+
        ecfs[0]['QCD_Pt_1800to2400_TuneCP5_13TeV_pythia8']['QCD_Pt_1800to2400']['D3']+
        ecfs[0]['QCD_Pt_2400to3200_TuneCP5_13TeV_pythia8']['QCD_Pt_2400to3200']['D3']+
        ecfs[0]['QCD_Pt_3200toInf_TuneCP5_13TeV_pythia8']['QCD_Pt_3200toInf']['D3'])

# %%
n4_bckgrd_total = qcd_n4[0:40:sum]

n4_false_positive = []
for i in range(1, 41):
    n4_false_positive.append(qcd_n4[0:i:sum].value/n4_bckgrd_total.value)
#n4_false_positive.insert(0,0)

n2_bckgrd_total = qcd_n2[0:40:sum]

n2_false_positive = []
for i in range(1, 41):
    n2_false_positive.append(qcd_n2[0:i:sum].value/n2_bckgrd_total.value)
#n4_false_positive.insert(0,0)

n3_bckgrd_total = qcd_n3[0:40:sum]

n3_false_positive = []
for i in range(1, 41):
    n3_false_positive.append(qcd_n3[0:i:sum].value/n3_bckgrd_total.value)
#n4_false_positive.insert(0,0)

d2_bckgrd_total = qcd_d2[0:40:sum]

d2_false_positive = []
for i in range(1, 41):
    d2_false_positive.append(qcd_d2[0:i:sum].value/d2_bckgrd_total.value)
#n4_false_positive.insert(0,0)

d3_bckgrd_total = qcd_d3[0:40:sum]

d3_false_positive = []
for i in range(1, 41):
    d3_false_positive.append(qcd_d3[0:i:sum].value/d3_bckgrd_total.value)
#n4_false_positive.insert(0,0)

# %%
fig, ax = plt.subplots()
ax.plot(hbb_n4_true_positive, n4_false_positive, linewidth=2.0, label='Hbb N4')
ax.plot(hbb_n3_true_positive, n3_false_positive, linewidth=2.0, label='Hbb N3')
ax.plot(hbb_d2_true_positive, d2_false_positive, linewidth=2.0, label='Hbb D2')
ax.plot(d3_false_positive, hbb_d3_true_positive, linewidth=2.0, label='Hbb D3')
ax.plot(hbb_n2_true_positive, n2_false_positive, linewidth=2.0, label='Hbb N2')

plt.xlabel("True Positive")
plt.ylabel("False Positive")
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(hgg_n4_true_positive, n4_false_positive, linewidth=2.0, label='Hgg N4')
ax.plot(hgg_n3_true_positive, n3_false_positive, linewidth=2.0, label='Hgg N3')
ax.plot(hgg_d2_true_positive, d2_false_positive, linewidth=2.0, label='Hgg D2')
ax.plot(hgg_d3_true_positive, d3_false_positive,  linewidth=2.0, label='Hgg D3')
ax.plot(hgg_n2_true_positive, n2_false_positive, linewidth=2.0, label='Hgg N2')

plt.xlabel("True Positive")
plt.ylabel("False Positive")
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend()

# %%
fig, ax = plt.subplots()

ax.plot(hbb_d2_true_positive, hgg_d2_true_positive, linewidth=2.0, label='D2')
ax.plot(hgg_n3_true_positive, hbb_n3_true_positive, linewidth=2.0, label='N3')
ax.plot(hgg_n4_true_positive, hbb_n4_true_positive, linewidth=2.0, label='N4')


plt.xlabel("True Positive")
plt.ylabel("False Positive")
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend()

# %%
with open("../../outputs/n4/multi_dim_axes/hgg.pkl", "rb") as f:
    hgg = pickle.load(f)
with open("../../outputs/n4/multi_dim_axes/hbb.pkl", "rb") as f:
    hbb = pickle.load(f)

# %%
fig, ax = plt.subplots()
hgg[0]['Hgg']['Hgg']["N3-4_D2"].project("D2B1", "N4B1").plot2d()
ax.set_title('Hgg D2/N4')
# Out:
# ...
#   Regular(40, 0, 3, underflow=False, overflow=False, name='D2B1'),
#   Regular(40, 0, 45, underflow=False, overflow=False, name='N4B1'),
#   storage=Weight()) # Sum: WeightedSum(value=254305, variance=254305)
# Text(0.5, 1.0, 'Hgg D2/N4')

# %%
fig, ax = plt.subplots()
hgg[0]['Hgg']['Hgg']["N3-4_D2"].project("N3B1", "N4B1").plot2d()
ax.set_title('Hgg N3/N4')
# Out:
# ...
#   Regular(40, 0, 3, underflow=False, overflow=False, name='N3B1'),
#   Regular(40, 0, 45, underflow=False, overflow=False, name='N4B1'),
#   storage=Weight()) # Sum: WeightedSum(value=254305, variance=254305)
# Text(0.5, 1.0, 'Hgg N3/N4')

# %%
#plt.scatter(test[0]['Hgg']['Hgg']['N3_vals'][:100], test[0]['Hgg']['Hgg']['N4_vals'][:100])
